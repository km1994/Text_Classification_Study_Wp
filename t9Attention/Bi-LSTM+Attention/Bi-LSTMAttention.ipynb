# %%
'''
    @Author: King
    @Date: 2019.03.18
    @Purpose: 文本分类实战（五）—— Bi-LSTM + Attention模型
    @Introduction:  下面介绍
    @Link : https://github.com/jiangxinyang227/textClassifier/tree/master/Bi-LSTM%2BAttention
    @Reference : https://www.cnblogs.com/jiangxinyang/p/10208227.html
'''

# %% [markdown]
# ## 数据集介绍
#
# 数据集为IMDB 电影影评，总共有三个数据文件，在/data/rawData目录下，包括unlabeledTrainData.tsv，labeledTrainData.tsv，testData.tsv。在进行文本分类时需要有标签的数据（labeledTrainData），数据预处理如文本分类实战（一）—— word2vec预训练词向量中一样，预处理后的文件为/data/preprocess/labeledTrain.csv。
#
#
# ##  Bi-LSTM + Attention 模型介绍
#
# Bi-LSTM + Attention模型来源于论文Attention-Based Bidirectional Long Short-Term Memory Networks for Relation Classification。关于Attention的介绍见这篇。
#
# Bi-LSTM + Attention 就是在Bi-LSTM的模型上加入Attention层，在Bi-LSTM中我们会用最后一个时序的输出向量 作为特征向量，然后进行softmax分类。Attention是先计算每个时序的权重，然后将所有时序 的向量进行加权和作为特征向量，然后进行softmax分类。在实验中，加上Attention确实对结果有所提升。其模型结构如下图：
#
# ![avatar](../images/BI-LSTM+Attention.png)

# %%
import os
import csv
import time
import datetime
import random
import json

import warnings
from collections import Counter
from math import sqrt

import gensim
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score
warnings.filterwarnings("ignore")
# Out:
# d:\progrom\python\python\python3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# d:\progrom\python\python\python3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# 配置参数

class TrainingConfig(object):
    epoches = 4
    evaluateEvery = 100
    checkpointEvery = 100
    learningRate = 0.001
    
class ModelConfig(object):
    embeddingSize = 200
    
    hiddenSizes = [256, 128]  # LSTM结构的神经元个数
    
    dropoutKeepProb = 0.5   
    l2RegLambda = 0.0
    
class Config(object):
    sequenceLength = 200  # 取了所有序列长度的均值
    batchSize = 128
    
    dataSource = "../data/preProcess/labeledTrain.csv"
    
    stopWordSource = "../data/english"
    
    numClasses = 2
    
    rate = 0.8  # 训练集的比例
    
    training = TrainingConfig()
    
    model = ModelConfig()

    
# 实例化配置参数对象
config = Config()

# %% [markdown]
# ## 生成训练数据
#
# 　　1）将数据加载进来，将句子分割成词表示，并去除低频词和停用词。
#
# 　　2）将词映射成索引表示，构建词汇-索引映射表，并保存成json的数据格式，之后做inference时可以用到。（注意，有的词可能不在word2vec的预训练词向量中，这种词直接用UNK表示）
#
# 　　3）从预训练的词向量模型中读取出词向量，作为初始化值输入到模型中。
#
# 　　4）将数据集分割成训练集和测试集

# %%
# 数据预处理的类，生成训练集和测试集

class Dataset(object):
    def __init__(self, config):
        self._dataSource = config.dataSource          # 数据文件路径
        self._stopWordSource = config.stopWordSource  # 分词文件路径
        
        self._sequenceLength = config.sequenceLength  # 每条输入的序列处理为定长
        self._embeddingSize = config.model.embeddingSize
        self._batchSize = config.batchSize
        self._rate = config.rate
        
        self._stopWordDict = {}
        
        self.trainReviews = []
        self.trainLabels = []
        
        self.evalReviews = []
        self.evalLabels = []
        
        self.wordEmbedding =None
        
        self._wordToIndex = {}
        self._indexToWord = {}
        
    def _readData(self, filePath):
        '''
        从csv文件中读取数据集
        
        :param filePath:   str   数据集文件路径
        :return:
            reviews:   list    数据集
            labels：   list    标签集
        '''
        df = pd.read_csv(filePath)
        labels = df["sentiment"].tolist()
        review = df["review"].tolist()
        reviews = [line.strip().split() for line in review]

        return reviews, labels

    def _reviewProcess(self, review, sequenceLength, wordToIndex):
        '''
        将数据集中的每条评论用index表示
        wordToIndex中“pad”对应的index为0
        
        :param review:   
        :param sequenceLength:  
        :return:
            reviewVec:   list    
        '''
        
        reviewVec = np.zeros((sequenceLength))
        sequenceLen = sequenceLength
        
        # 判断当前的序列是否小于定义的固定序列长度
        if len(review) < sequenceLength:
            sequenceLen = len(review)
            
        for i in range(sequenceLen):
            if review[i] in wordToIndex:
                reviewVec[i] = wordToIndex[review[i]]
            else:
                reviewVec[i] = wordToIndex["UNK"]

        return reviewVec

    def _genTrainEvalData(self, x, y, rate):
        '''
        生成训练集和验证集
        
        :param x:     list     数据
        :param y:     list     数据标签
        :param rate:  float    分割比例
        :return:
            trainReviews:   list    
            trainLabels:   list    
            evalReviews:   list    
            evalLabels:   list    
        '''
        reviews = []
        labels = []
        
        # 遍历所有的文本，将文本中的词转换成index表示
        for i in range(len(x)):
            reviewVec = self._reviewProcess(x[i], self._sequenceLength, self._wordToIndex)
            reviews.append(reviewVec)
            
            labels.append([y[i]])
            
        trainIndex = int(len(x) * rate)
        
        trainReviews = np.asarray(reviews[:trainIndex], dtype="int64")
        trainLabels = np.array(labels[:trainIndex], dtype="float32")
        
        evalReviews = np.asarray(reviews[trainIndex:], dtype="int64")
        evalLabels = np.array(labels[trainIndex:], dtype="float32")

        return trainReviews, trainLabels, evalReviews, evalLabels
        
    def _genVocabulary(self, reviews):
        '''
        生成词向量和词汇-索引映射字典，可以用全数据集
        
        :param reviews:     list     数据
        :return:
            
        '''
        
        allWords = [word for review in reviews for word in review]
        
        # 去掉停用词
        subWords = [word for word in allWords if word not in self.stopWordDict]
        
        wordCount = Counter(subWords)  # 统计词频
        sortWordCount = sorted(wordCount.items(), key=lambda x: x[1], reverse=True)
        
        # 去除低频词
        words = [item[0] for item in sortWordCount if item[1] >= 5]
        
        vocab, wordEmbedding = self._getWordEmbedding(words)
        self.wordEmbedding = wordEmbedding
        
        self._wordToIndex = dict(zip(vocab, list(range(len(vocab)))))
        self._indexToWord = dict(zip(list(range(len(vocab))), vocab))
        
        # 将词汇-索引映射表保存为json数据，之后做inference时直接加载来处理数据
        with open("../data/wordJson/wordToIndex.json", "w", encoding="utf-8") as f:
            json.dump(self._wordToIndex, f)
        
        with open("../data/wordJson/indexToWord.json", "w", encoding="utf-8") as f:
            json.dump(self._indexToWord, f)
            
    def _getWordEmbedding(self, words):
        '''
        按照我们的数据集中的单词取出预训练好的word2vec中的词向量
        
        :param words:     list     数据
        :return:
             vocab                       list            词列表
             np.array(wordEmbedding)     numpy array     词向量
            
        '''
        
        wordVec = gensim.models.KeyedVectors.load_word2vec_format("../word2vec/word2Vec.bin", binary=True)
        vocab = []
        wordEmbedding = []
        
        # 添加 "pad" 和 "UNK", 
        vocab.append("pad")
        vocab.append("UNK")
        wordEmbedding.append(np.zeros(self._embeddingSize))
        wordEmbedding.append(np.zeros(self._embeddingSize))
        
        for word in words:
            try:
                vector = wordVec.wv[word]
                vocab.append(word)
                wordEmbedding.append(vector)
            except:
                print(word + "不存在于词向量中")
                
        return vocab, np.array(wordEmbedding)
    
    def _readStopWord(self, stopWordPath):
        '''
        读取停用词
        
        :param stopWordPath:     str     停用词文件路径
        :return: 
            
        '''

        with open(stopWordPath, "r") as f:
            stopWords = f.read()
            stopWordList = stopWords.splitlines()
            # 将停用词用列表的形式生成，之后查找停用词时会比较快
            self.stopWordDict = dict(zip(stopWordList, list(range(len(stopWordList)))))
            
    def dataGen(self):
        '''
         初始化训练集和验证集
        
        :param :
        :return: 
            
        '''
        
        # 初始化停用词
        self._readStopWord(self._stopWordSource)
        
        # 初始化数据集
        reviews, labels = self._readData(self._dataSource)
        
        # 初始化词汇-索引映射表和词向量矩阵
        self._genVocabulary(reviews)
        
        # 初始化训练集和测试集
        trainReviews, trainLabels, evalReviews, evalLabels = self._genTrainEvalData(reviews, labels, self._rate)
        self.trainReviews = trainReviews
        self.trainLabels = trainLabels
        
        self.evalReviews = evalReviews
        self.evalLabels = evalLabels
        
        
data = Dataset(config)
data.dataGen()
# Out:
# youre不存在于词向量中
# youll不存在于词向量中
# theyre不存在于词向量中
# youve不存在于词向量中
# werent不存在于词向量中
# youd不存在于词向量中
# hasnt不存在于词向量中
# shouldnt不存在于词向量中
# weve不存在于词向量中
# theyve不存在于词向量中
# 1010不存在于词向量中
# wouldve不存在于词向量中
# hed不存在于词向量中
# andor不存在于词向量中
# couldve不存在于词向量中
# 810不存在于词向量中
# itthe不存在于词向量中
# 710不存在于词向量中
# theyd不存在于词向量中
# writerdirector不存在于词向量中
# moviei不存在于词向量中
# iti不存在于词向量中
# theyll不存在于词向量中
# 310不存在于词向量中
# 410不存在于词向量中
# 910不存在于词向量中
# itll不存在于词向量中
# lees不存在于词向量中
# familys不存在于词向量中
# disneys不存在于词向量中
# filmi不存在于词向量中
# 210不存在于词向量中
# shouldve不存在于词向量中
# *12不存在于词向量中
# shakespeares不存在于词向量中
# hitlers不存在于词向量中
# brazil:不存在于词向量中
# freddys不存在于词向量中
# fords不存在于词向量中
# storys不存在于词向量中
# ohara不存在于词向量中
# stewarts不存在于词向量中
# kellys不存在于词向量中
# scotts不存在于词向量中
# itthis不存在于词向量中
# tonys不存在于词向量中
# keatons不存在于词向量中
# rosemarys不存在于词向量中
# ches不存在于词向量中
# themthe不存在于词向量中
# timethe不存在于词向量中
# branaghs不存在于词向量中
# mustve不存在于词向量中
# kubricks不存在于词向量中
# lynchs不存在于词向量中
# hitchcocks不存在于词向量中
# bakshis不存在于词向量中
# whove不存在于词向量中
# allthe不存在于词向量中
# whod不存在于词向量中
# smiths不存在于词向量中
# itit不存在于词向量中
# obrien不存在于词向量中
# cravens不存在于词向量中
# timei不存在于词向量中
# movieit不存在于词向量中
# palmas不存在于词向量中
# himthe不存在于词向量中
# itbut不存在于词向量中
# waythe不存在于词向量中
# altmans不存在于词向量中
# hartleys不存在于词向量中
# methe不存在于词向量中
# storythe不存在于词向量中
# taime不存在于词向量中
# romeros不存在于词向量中
# filmit不存在于词向量中
# verhoevens不存在于词向量中
# filmthis不存在于词向量中
# countrys不存在于词向量中
# oneill不存在于词向量中
# eastwoods不存在于词向量中
# miyazakis不存在于词向量中
# 010不存在于词向量中
# sinatras不存在于词向量中
# everybodys不存在于词向量中
# movieand不存在于词向量中
# citys不存在于词向量中
# thatll不存在于词向量中
# harrys不存在于词向量中
# cmon不存在于词向量中
# victorias不存在于词向量中
# movieits不存在于词向量中
# hisher不存在于词向量中
# pauls不存在于词向量中
# itd不存在于词向量中
# goodthe不存在于词向量中
# spielbergs不存在于词向量中
# imdbs不存在于词向量中
# moviethis不存在于词向量中
# streisands不存在于词向量中
# gilligans不存在于词向量中
# actorsactresses不存在于词向量中
# pacinos不存在于词向量中
# teds不存在于词向量中
# itits不存在于词向量中
# otoole不存在于词向量中
# ladys不存在于词向量中
# heshe不存在于词向量中
# fulcis不存在于词向量中
# bens不存在于词向量中
# badthe不存在于词向量中
# austens不存在于词向量中
# singin不存在于词向量中
# onethe不存在于词向量中
# herethe不存在于词向量中
# therethe不存在于词向量中
# alli不存在于词向量中
# directorwriter不存在于词向量中
# osullivan不存在于词向量中
# wellthe不存在于词向量中
# elviras不存在于词向量中
# arthurs不存在于词向量中
# taylors不存在于词向量中
# cusacks不存在于词向量中
# nobodys不存在于词向量中
# brandos不存在于词向量中
# thisthe不存在于词向量中
# goldsworthys不存在于词向量中
# betterthe不存在于词向量中
# lifethe不存在于词向量中
# toothe不存在于词向量中
# londons不存在于词向量中
# youngs不存在于词向量中
# itif不存在于词向量中
# joes不存在于词向量中
# jims不存在于词向量中
# manns不存在于词向量中
# burtons不存在于词向量中
# kurosawas不存在于词向量中
# horrorthriller不存在于词向量中
# johnsons不存在于词向量中
# thati不存在于词向量中
# toms不存在于词向量中
# dereks不存在于词向量中
# santas不存在于词向量中
# onthe不存在于词向量中
# isthe不存在于词向量中
# powells不存在于词向量中
# thisi不存在于词向量中
# oneal不存在于词向量中
# caines不存在于词向量中
# moviethere不存在于词向量中
# chaplins不存在于词向量中
# dawsons不存在于词向量中
# soderberghs不存在于词向量中
# outthe不存在于词向量中
# lincolns不存在于词向量中
# moviesthe不存在于词向量中
# stanwycks不存在于词向量中
# funnyi不存在于词向量中
# themthis不存在于词向量中
# fromthe不存在于词向量中
# erics不存在于词向量中
# andys不存在于词向量中
# herthe不存在于词向量中
# againthe不存在于词向量中
# flynns不存在于词向量中
# logans不存在于词向量中
# tolkiens不存在于词向量中
# worldthe不存在于词向量中
# stallones不存在于词向量中
# charactersthe不存在于词向量中
# moviebut不存在于词向量中
# henrys不存在于词向量中
# jackies不存在于词向量中
# marys不存在于词向量中
# funnythe不存在于词向量中
# oni不存在于词向量中
# rolethe不存在于词向量中
# neednt不存在于词向量中
# annas不存在于词向量中
# sirks不存在于词向量中
# yorks不存在于词向量中
# ;-不存在于词向量中
# brontes不存在于词向量中
# antonionis不存在于词向量中
# capotes不存在于词向量中
# anns不存在于词向量中
# morethe不存在于词向量中
# vonneguts不存在于词向量中
# satans不存在于词向量中
# gilliams不存在于词向量中
# washingtons不存在于词向量中
# goodi不存在于词向量中
# 510不存在于词向量中
# glovers不存在于词向量中
# mightve不存在于词向量中
# oclock不存在于词向量中
# sullivans不存在于词向量中
# 610不存在于词向量中
# ***12不存在于词向量中
# polanskis不存在于词向量中
# lukes不存在于词向量中
# russells不存在于词向量中
# macarthurs不存在于词向量中
# timesthe不存在于词向量中
# dannys不存在于词向量中
# sutherlands不存在于词向量中
# rachels不存在于词向量中
# carreys不存在于词向量中
# itin不存在于词向量中
# madonnas不存在于词向量中
# isi不存在于词向量中
# plotthe不存在于词向量中
# companys不存在于词向量中
# drews不存在于词向量中
# screenthe不存在于词向量中
# itand不存在于词向量中
# societys不存在于词向量中
# endi不存在于词向量中
# endthe不存在于词向量中
# zizeks不存在于词向量中
# merk不存在于词向量中
# shaws不存在于词向量中
# seenthe不存在于词向量中
# filmbut不存在于词向量中
# minutesthe不存在于词向量中
# filmif不存在于词向量中
# wayi不存在于词向量中
# scenesthe不存在于词向量中
# mgms不存在于词向量中
# garbos不存在于词向量中
# scorseses不存在于词向量中
# lifei不存在于词向量中
# imdbcom不存在于词向量中
# premingers不存在于词向量中
# carlas不存在于词向量中
# themi不存在于词向量中
# dangelo不存在于词向量中
# aboutthe不存在于词向量中
# beattys不存在于词向量中
# girlfight不存在于词向量中
# threes不存在于词向量中
# betties不存在于词向量中
# langs不存在于词向量中
# 7510不存在于词向量中
# 8510不存在于词向量中
# hoffmans不存在于词向量中
# hardys不存在于词向量中
# badi不存在于词向量中
# actionadventure不存在于词向量中
# rochesters不存在于词向量中
# wholl不存在于词向量中
# millers不存在于词向量中
# lugosis不存在于词向量中
# penns不存在于词向量中
# upthe不存在于词向量中
# matthaus不存在于词向量中
# seriesthe不存在于词向量中
# als不存在于词向量中
# walkens不存在于词向量中
# oliviers不存在于词向量中
# parkers不存在于词向量中
# filmand不存在于词向量中
# rockin不存在于词向量中
# eddies不存在于词向量中
# kyles不存在于词向量中
# cuckoos不存在于词向量中
# bethe不存在于词向量中
# supermans不存在于词向量中
# clarks不存在于词向量中
# bos不存在于词向量中
# storyi不存在于词向量中
# filma不存在于词向量中
# fondas不存在于词向量中
# gordons不存在于词向量中
# det不存在于词向量中
# etcthe不存在于词向量中
# sp不存在于词向量中
# johnnys不存在于词向量中
# fullers不存在于词向量中
# lilys不存在于词向量中
# gilleys不存在于词向量中
# thompsons不存在于词向量中
# lennons不存在于词向量中
# characterthe不存在于词向量中
# cohens不存在于词向量中
# moviesthis不存在于词向量中
# welli不存在于词向量中
# freemans不存在于词向量中
# kates不存在于词向量中
# dexters不存在于词向量中
# harlins不存在于词向量中
# cains不存在于词向量中
# goauld不存在于词向量中
# movieif不存在于词向量中
# anybodys不存在于词向量中
# mummys不存在于词向量中
# adv不存在于词向量中
# wagners不存在于词向量中
# eighttitle不存在于词向量中
# nicholsons不存在于词向量中
# filmin不存在于词向量中
# jerrys不存在于词向量中
# familythe不存在于词向量中
# annes不存在于词向量中
# wasi不存在于词向量中
# dixons不存在于词向量中
# paulies不存在于词向量中
# levins不存在于词向量中
# woodys不存在于词向量中
# onei不存在于词向量中
# ollies不存在于词向量中
# filmsthe不存在于词向量中
# japans不存在于词向量中
# maughams不存在于词向量中
# alices不存在于词向量中
# rukhs不存在于词向量中
# storythis不存在于词向量中
# moviea不存在于词向量中
# actingthe不存在于词向量中
# brosnans不存在于词向量中
# daythe不存在于词向量中
# bruces不存在于词向量中
# crashers不存在于词向量中
# bolls不存在于词向量中
# panahis不存在于词向量中
# jrs不存在于词向量中
# muchthe不存在于词向量中
# englands不存在于词向量中
# bikos不存在于词向量中
# visiteurs不存在于词向量中
# alexs不存在于词向量中
# novaks不存在于词向量中
# widmarks不存在于词向量中
# damato不存在于词向量中
# emmas不存在于词向量中
# porkys不存在于词向量中
# nancys不存在于词向量中
# carters不存在于词向量中
# watchthe不存在于词向量中
# lovehate不存在于词向量中
# actoractress不存在于词向量中
# workthe不存在于词向量中
# christys不存在于词向量中
# morgans不存在于词向量中
# lumets不存在于词向量中
# attenboroughs不存在于词向量中
# rohmers不存在于词向量中
# perrys不存在于词向量中
# $10000不存在于词向量中
# notthe不存在于词向量中
# hestons不存在于词向量中
# moviesi不存在于词向量中
# gibsons不存在于词向量中
# cormans不存在于词向量中
# lundgrens不存在于词向量中
# youthe不存在于词向量中
# frankies不存在于词向量中
# thirdly不存在于词向量中
# itthere不存在于词向量中
# camerons不存在于词向量中
# movieso不存在于词向量中
# viscontis不存在于词向量中
# betteri不存在于词向量中
# filmmy不存在于词向量中
# poes不存在于词向量中
# goodbut不存在于词向量中
# ita不存在于词向量中
# universals不存在于词向量中
# streeps不存在于词向量中
# funi不存在于词向量中
# peckinpahs不存在于词向量中
# quinns不存在于词向量中
# againi不存在于词向量中
# argentos不存在于词向量中
# christs不存在于词向量中
# karloffs不存在于词向量中
# sidneys不存在于词向量中
# anywaythe不存在于词向量中
# timethis不存在于词向量中
# pecks不存在于词向量中
# falks不存在于词向量中
# naschys不存在于词向量中
# lis不存在于词向量中
# jabbas不存在于词向量中
# connerys不存在于词向量中
# showthe不存在于词向量中
# filmso不存在于词向量中
# bbcs不存在于词向量中
# timmys不存在于词向量中
# fishburnes不存在于词向量中
# heri不存在于词向量中
# maries不存在于词向量中
# thoughthe不存在于词向量中
# didthe不存在于词向量中
# oshea不存在于词向量中
# neds不存在于词向量中
# timons不存在于词向量中
# corbetts不存在于词向量中
# filmthere不存在于词向量中
# wilders不存在于词向量中
# khouris不存在于词向量中
# putain不存在于词向量中
# steves不存在于词向量中
# oconnor不存在于词向量中
# rien不存在于词向量中
# razors不存在于词向量中
# crowes不存在于词向量中
# tealc不存在于词向量中
# wrongi不存在于词向量中
# dominos不存在于词向量中
# duvalls不存在于词向量中
# filmits不存在于词向量中
# donnas不存在于词向量中
# australias不存在于词向量中
# kazans不存在于词向量中
# bergmans不存在于词向量中
# endthis不存在于词向量中
# candys不存在于词向量中
# ritters不存在于词向量中
# itwhat不存在于词向量中
# filmsi不存在于词向量中
# martinos不存在于词向量中
# barkers不存在于词向量中
# youi不存在于词向量中
# audiencethe不存在于词向量中
# ityou不存在于词向量中
# felixs不存在于词向量中
# leos不存在于词向量中
# greatthe不存在于词向量中
# geddes不存在于词向量中
# seeni不存在于词向量中
# herei不存在于词向量中
# babys不存在于词向量中
# wellit不存在于词向量中
# thisthis不存在于词向量中
# no1不存在于词向量中
# lesters不存在于词向量中
# gershwins不存在于词向量中
# alisons不存在于词向量中
# newmans不存在于词向量中
# fallons不存在于词向量中
# gannons不存在于词向量中
# tooi不存在于词向量中
# jimmys不存在于词向量中
# petes不存在于词向量中
# somebodys不存在于词向量中
# amazoncom不存在于词向量中
# macys不存在于词向量中
# lifethis不存在于词向量中
# mabels不存在于词向量中
# madethe不存在于词向量中
# dont!不存在于词向量中
# sarahs不存在于词向量中
# wrongthe不存在于词向量中
# seventitle不存在于词向量中
# fellinis不存在于词向量中
# wendys不存在于词向量中
# moviein不存在于词向量中
# tarantinos不存在于词向量中
# kiplings不存在于词向量中
# hustons不存在于词向量中
# experiencethe不存在于词向量中
# abcs不存在于词向量中
# susans不存在于词向量中
# movieyou不存在于词向量中
# unfilmable不存在于词向量中
# manthe不存在于词向量中
# noti不存在于词向量中
# timein不存在于词向量中
# showi不存在于词向量中
# hepburns不存在于词向量中
# belushis不存在于词向量中
# harts不存在于词向量中
# joeys不存在于词向量中
# steiners不存在于词向量中
# lemmons不存在于词向量中
# batmans不存在于词向量中
# tarzans不存在于词向量中
# methis不存在于词向量中
# luzhins不存在于词向量中
# versionthe不存在于词向量中
# dothe不存在于词向量中
# peoplethe不存在于词向量中
# eberts不存在于词向量中
# hoopers不存在于词向量中
# einsteins不存在于词向量中
# stillers不存在于词向量中
# wilsons不存在于词向量中
# wellthis不存在于词向量中
# leonards不存在于词向量中
# sic不存在于词向量中
# kaufmans不存在于词向量中
# ritchies不存在于词向量中
# alans不存在于词向量中
# pointthe不存在于词向量中
# comedys不存在于词向量中
# guevaras不存在于词向量中
# thingi不存在于词向量中
# sebergs不存在于词向量中
# roegs不存在于词向量中
# 2the不存在于词向量中
# greenaways不存在于词向量中
# itas不存在于词向量中
# brontës不存在于词向量中
# fishers不存在于词向量中
# gandhis不存在于词向量中
# tracys不存在于词向量中
# everythings不存在于词向量中
# nowi不存在于词向量中
# poseys不存在于词向量中
# godards不存在于词向量中
# carells不存在于词向量中
# lilas不存在于词向量中
# burtynskys不存在于词向量中
# disappointedthe不存在于词向量中
# therei不存在于词向量中
# jennifers不存在于词向量中
# otherthe不存在于词向量中
# snitchd不存在于词向量中
# roys不存在于词向量中
# celestes不存在于词向量中
# mamets不存在于词向量中
# itso不存在于词向量中
# togetherthe不存在于词向量中
# herebut不存在于词向量中
# oconor不存在于词向量中
# decameron不存在于词向量中
# churchs不存在于词向量中
# beforethe不存在于词向量中
# muchi不存在于词向量中
# iberia不存在于词向量中
# scriptthe不存在于词向量中
# pasolinis不存在于词向量中
# filmsthis不存在于词向量中
# leones不存在于词向量中
# boyles不存在于词向量中
# kristoffersons不存在于词向量中
# lewiss不存在于词向量中
# rolesthe不存在于词向量中
# himand不存在于词向量中
# farrells不存在于词向量中
# josephs不存在于词向量中
# astaires不存在于词向量中
# niros不存在于词向量中
# familyi不存在于词向量中
# worldi不存在于词向量中
# reasonthe不存在于词向量中
# bournes不存在于词向量中
# eitherthe不存在于词向量中
# realthe不存在于词向量中
# placethe不存在于词向量中
# hilariousthe不存在于词向量中
# rooneys不存在于词向量中
# boringi不存在于词向量中
# onthis不存在于词向量中
# thatthis不存在于词向量中
# ryans不存在于词向量中
# hydes不存在于词向量中
# antwones不存在于词向量中
# kims不存在于词向量中
# harlows不存在于词向量中
# yetis不存在于词向量中
# crapi不存在于词向量中
# seriesi不存在于词向量中
# partthe不存在于词向量中
# jamess不存在于词向量中
# cagneys不存在于词向量中
# movieone不存在于词向量中
# stroker不存在于词向量中
# modestys不存在于词向量中
# odonnell不存在于词向量中
# corsaut不存在于词向量中
# casethe不存在于词向量中
# oneand不存在于词向量中
# codys不存在于词向量中
# foxs不存在于词向量中
# itselfi不存在于词向量中
# oconnell不存在于词向量中
# fassbinders不存在于词向量中
# moviewell不存在于词向量中
# eitheri不存在于词向量中
# cushings不存在于词向量中
# pixars不存在于词向量中
# moviedont不存在于词向量中
# tpol不存在于词向量中
# hudsons不存在于词向量中
# humanitys不存在于词向量中
# wallaces不存在于词向量中
# lintrus不存在于词向量中
# grendels不存在于词向量中
# gables不存在于词向量中
# effectsthe不存在于词向量中
# lovethe不存在于词向量中
# yikes不存在于词向量中
# elliotts不存在于词向量中
# booki不存在于词向量中
# historythe不存在于词向量中
# moviesbut不存在于词向量中
# oneil不存在于词向量中
# greenes不存在于词向量中
# indias不存在于词向量中
# outi不存在于词向量中
# jaffa不存在于词向量中
# badbut不存在于词向量中
# screeni不存在于词向量中
# bacons不存在于词向量中
# dor不存在于词向量中
# againit不存在于词向量中
# sagemiller不存在于词向量中
# timeand不存在于词向量中
# onethis不存在于词向量中
# thingsthe不存在于词向量中
# daddys不存在于词向量中
# porters不存在于词向量中
# itim不存在于词向量中
# wellbut不存在于词向量中
# worsethe不存在于词向量中
# sauras不存在于词向量中
# todds不存在于词向量中
# goyokin不存在于词向量中
# moviemy不存在于词向量中
# presque不存在于词向量中
# demilles不存在于词向量中
# columbos不存在于词向量中
# segals不存在于词向量中
# sweetin不存在于词向量中
# wests不存在于词向量中
# ruths不存在于词向量中
# withthe不存在于词向量中
# interestingthe不存在于词向量中
# bosss不存在于词向量中
# lifeit不存在于词向量中
# crapthe不存在于词向量中
# nwh不存在于词向量中
# esthers不存在于词向量中
# cb4不存在于词向量中
# fatherson不存在于词向量中
# foxxs不存在于词向量中
# daysthe不存在于词向量中
# anothers不存在于词向量中
# joans不存在于词向量中
# granddaughters不存在于词向量中
# brians不存在于词向量中
# goodthis不存在于词向量中
# arnolds不存在于词向量中
# 10000不存在于词向量中
# funthe不存在于词向量中
# timesbut不存在于词向量中
# colmans不存在于词向量中
# offi不存在于词向量中
# realitythe不存在于词向量中
# himthis不存在于词向量中
# rev不存在于词向量中
# caligari不存在于词向量中
# umm不存在于词向量中
# robertsons不存在于词向量中
# billys不存在于词向量中
# cheadles不存在于词向量中
# kidmans不存在于词向量中
# himi不存在于词向量中
# comedythe不存在于词向量中
# nelsons不存在于词向量中
# horrorcomedy不存在于词向量中
# dahmers不存在于词向量中
# timesi不存在于词向量中
# francos不存在于词向量中
# filmwhat不存在于词向量中
# ummm不存在于词向量中
# tothe不存在于词向量中
# sabrinas不存在于词向量中
# vasey不存在于词向量中
# shin-aes不存在于词向量中
# terriblethe不存在于词向量中
# daviss不存在于词向量中
# warthe不存在于词向量中
# knowthe不存在于词向量中
# leighs不存在于词向量中
# karens不存在于词向量中
# yentl不存在于词向量中
# bronsons不存在于词向量中
# badit不存在于词向量中
# isthis不存在于词向量中
# cassidys不存在于词向量中
# doyles不存在于词向量中
# addy不存在于词向量中
# recap:不存在于词向量中
# rocknroll不存在于词向量中
# toi不存在于词向量中
# marias不存在于词向量中
# latters不存在于词向量中
# vice-versa不存在于词向量中
# roths不存在于词向量中
# $1000000不存在于词向量中
# filmone不存在于词向量中
# filmas不存在于词向量中
# experiencei不存在于词向量中
# bestthe不存在于词向量中
# allit不存在于词向量中
# fatherthe不存在于词向量中
# alberts不存在于词向量中
# greendale不存在于词向量中
# schumachers不存在于词向量中
# doone不存在于词向量中
# spoilersi不存在于词向量中
# ursulas不存在于词向量中
# nablus不存在于词向量中
# euripides不存在于词向量中
# harveys不存在于词向量中
# youit不存在于词向量中
# thatbut不存在于词向量中
# mankinds不存在于词向量中
# boyers不存在于词向量中
# differentthe不存在于词向量中
# walkin不存在于词向量中
# voights不存在于词向量中
# paltrows不存在于词向量中
# lius不存在于词向量中
# robins不存在于词向量中
# redgraves不存在于词向量中
# brotherthe不存在于词向量中
# bunuels不存在于词向量中
# caesars不存在于词向量中
# crosbys不存在于词向量中
# spocks不存在于词向量中
# tierneys不存在于词向量中
# chers不存在于词向量中
# timeits不存在于词向量中
# therere不存在于词向量中
# chinas不存在于词向量中
# cannavale不存在于词向量中
# scarlets不存在于词向量中
# starsthe不存在于词向量中
# lubitschs不存在于词向量中
# pickfords不存在于词向量中
# peepers不存在于词向量中
# facethe不存在于词向量中
# garys不存在于词向量中
# allendes不存在于词向量中
# frankensteins不存在于词向量中
# actorsthe不存在于词向量中
# christines不存在于词向量中
# timea不存在于词向量中
# hima不存在于词向量中
# noltes不存在于词向量中
# wasis不存在于词向量中
# mayors不存在于词向量中
# orwells不存在于词向量中
# brendans不存在于词向量中
# bloss不存在于词向量中
# malfatti不存在于词向量中
# barrymores不存在于词向量中
# sadthe不存在于词向量中
# castthe不存在于词向量中
# edisons不存在于词向量中
# knowi不存在于词向量中
# dahls不存在于词向量中
# walshs不存在于词向量中
# timeif不存在于词向量中
# offthe不存在于词向量中
# draculas不存在于词向量中
# reids不存在于词向量中
# pythons不存在于词向量中
# tiffanys不存在于词向量中
# itfor不存在于词向量中
# rafiki不存在于词向量中
# labours不存在于词向量中
# yaara不存在于词向量中
# hamlets不存在于词向量中
# chens不存在于词向量中
# allits不存在于词向量中
# sm不存在于词向量中
# seans不存在于词向量中
# julians不存在于词向量中
# anywayi不存在于词向量中
# wasthe不存在于词向量中
# itall不存在于词向量中
# happenthe不存在于词向量中
# throughi不存在于词向量中
# fays不存在于词向量中
# deaththe不存在于词向量中
# 2036不存在于词向量中
# outthis不存在于词向量中
# oleary不存在于词向量中
# toothis不存在于词向量中
# sants不存在于词向量中
# coulardeau不存在于词向量中
# dogville不存在于词向量中
# grays不存在于词向量中
# upi不存在于词向量中
# somethingi不存在于词向量中
# banjos不存在于词向量中
# moi不存在于词向量中
# bei不存在于词向量中
# inthe不存在于词向量中
# gillians不存在于词向量中
# backthe不存在于词向量中
# momentsthe不存在于词向量中
# donethe不存在于词向量中
# gromit不存在于词向量中
# menstruation不存在于词向量中
# 999%不存在于词向量中
# grinchs不存在于词向量中
# aroundthe不存在于词向量中
# ritas不存在于词向量中
# pandoras不存在于词向量中
# christies不存在于词向量中
# oconnors不存在于词向量中
# coles不存在于词向量中
# gentileschi不存在于词向量中
# moviedo不存在于词向量中
# alienator不存在于词向量中
# $100000不存在于词向量中
# graysons不存在于词向量中
# thingthe不存在于词向量中
# themthere不存在于词向量中
# peggs不存在于词向量中
# cmon!不存在于词向量中
# ksun不存在于词向量中
# canadas不存在于词向量中
# worki不存在于词向量中
# okay!不存在于词向量中
# shahs不存在于词向量中
# armstrongs不存在于词向量中
# clays不存在于词向量中
# natalis不存在于词向量中
# ohearn不存在于词向量中
# genrethe不存在于词向量中
# shantytown不存在于词向量中
# atlantian不存在于词向量中
# bagman不存在于词向量中
# maetel不存在于词向量中
# baldwins不存在于词向量中
# actioncomedy不存在于词向量中
# montanas不存在于词向量中
# mclaglens不存在于词向量中
# matata不存在于词向量中
# eyesthe不存在于词向量中
# louiss不存在于词向量中
# simbas不存在于词向量中
# movieall不存在于词向量中
# himher不存在于词向量中
# muertos不存在于词向量中
# lucys不存在于词向量中
# blithe不存在于词向量中
# chibas不存在于词向量中
# videodvd不存在于词向量中
# tronje不存在于词向量中
# prag不存在于词向量中
# musicthe不存在于词向量中
# lorens不存在于词向量中
# etcand不存在于词向量中
# kitchens不存在于词向量中
# storylinethe不存在于词向量中
# schwarzeneggers不存在于词向量中
# periodthe不存在于词向量中
# masseys不存在于词向量中
# 10i不存在于词向量中
# endingi不存在于词向量中
# 50000不存在于词向量中
# himin不存在于词向量中
# itwe不存在于词向量中
# wellif不存在于词向量中
# vidals不存在于词向量中
# solomons不存在于词向量中
# untergang不存在于词向量中
# kongs不存在于词向量中
# depalmas不存在于词向量中
# goodand不存在于词向量中
# fiancés不存在于词向量中
# larrys不存在于词向量中
# heinleins不存在于词向量中
# wodehouses不存在于词向量中
# raimis不存在于词向量中
# nortons不存在于词向量中
# etci不存在于词向量中
# :o不存在于词向量中
# reas不存在于词向量中
# everthe不存在于词向量中
# spanglish不存在于词向量中
# paynes不存在于词向量中
# themselvesthe不存在于词向量中
# luque不存在于词向量中
# johnny!不存在于词向量中
# thered不存在于词向量中
# onethere不存在于词向量中
# rhys-meyers不存在于词向量中
# lanzas不存在于词向量中
# liottas不存在于词向量中
# characterand不存在于词向量中
# deniros不存在于词向量中
# awfulthe不存在于词向量中
# studi不存在于词向量中
# madsens不存在于词向量中
# simms不存在于词向量中
# kitamuras不存在于词向量中
# bolkan不存在于词向量中
# helpers不存在于词向量中
# filmdont不存在于词向量中
# horrorsci-fi不存在于词向量中
# thatif不存在于词向量中
# stanleys不存在于词向量中
# ini不存在于词向量中
# rs不存在于词向量中
# redline不存在于词向量中
# houseboat不存在于词向量中
# mackendrick不存在于词向量中
# themin不存在于词向量中
# actorsi不存在于词向量中
# historys不存在于词向量中
# slovenia不存在于词向量中
# soso不存在于词向量中
# kundry不存在于词向量中
# hitler:不存在于词向量中
# yearsthe不存在于词向量中
# fourtitle不存在于词向量中
# rg不存在于词向量中
# familythis不存在于词向量中
# therethis不存在于词向量中
# bouzaglo不存在于词向量中
# gregorys不存在于词向量中
# jesss不存在于词向量中
# thereand不存在于词向量中
# 00s不存在于词向量中
# mcqueens不存在于词向量中
# tyrannus不存在于词向量中
# specialthe不存在于词向量中
# edies不存在于词向量中
# threetitle不存在于词向量中
# againand不存在于词向量中
# basra不存在于词向量中
# originalthe不存在于词向量中
# scenesi不存在于词向量中
# ninetitle不存在于词向量中
# rightthe不存在于词向量中
# allthis不存在于词向量中
# anyonethe不存在于词向量中
# musici不存在于词向量中
# waythis不存在于词向量中
# arrondissement不存在于词向量中
# grahams不存在于词向量中
# mindthe不存在于词向量中
# donei不存在于词向量中
# cf不存在于词向量中
# niki不存在于词向量中
# thatd不存在于词向量中
# meso不存在于词向量中
# mysterythriller不存在于词向量中
# mamas不存在于词向量中
# gespenster不存在于词向量中
# earththe不存在于词向量中
# bobbys不存在于词向量中
# blakes不存在于词向量中
# hoppers不存在于词向量中
# charactersi不存在于词向量中
# thisits不存在于词向量中
# matarazzo不存在于词向量中
# believablethe不存在于词向量中
# thisit不存在于词向量中
# thisbut不存在于词向量中
# prizzis不存在于词向量中
# shotthe不存在于词向量中
# zanes不存在于词向量中
# $399不存在于词向量中
# sicas不存在于词向量中
# releasedthe不存在于词向量中
# notthis不存在于词向量中
# geres不存在于词向量中
# conaway不存在于词向量中
# kopins不存在于词向量中
# oooh不存在于词向量中
# itselfthe不存在于词向量中
# dosent不存在于词向量中
# abouti不存在于词向量中
# heartthe不存在于词向量中
# clooneys不存在于词向量中
# announcers不存在于词向量中
# 185:1不存在于词向量中
# aka:不存在于词向量中
# todos不存在于词向量中
# dannings不存在于词向量中
# livesthe不存在于词向量中
# lisas不存在于词向量中
# overi不存在于词向量中
# weirs不存在于词向量中
# grot不存在于词向量中
# afis不存在于词向量中
# mt不存在于词向量中
# lawton不存在于词向量中
# jellybean不存在于词向量中
# kornman不存在于词向量中
# genies不存在于词向量中
# joness不存在于词向量中
# afflecks不存在于词向量中
# besti不存在于词向量中
# paines不存在于词向量中
# meit不存在于词向量中
# becks不存在于词向量中
# lengle不存在于词向量中
# uhm不存在于词向量中
# offthis不存在于词向量中
# kusturicas不存在于词向量中
# quaids不存在于词向量中
# klines不存在于词向量中
# himselfthe不存在于词向量中
# eds不存在于词向量中
# macleans不存在于词向量中
# 20000不存在于词向量中
# grasshopper不存在于词向量中
# movieeven不存在于词向量中
# timeit不存在于词向量中
# wasthis不存在于词向量中
# longthe不存在于词向量中
# phlox不存在于词向量中
# timesthis不存在于词向量中
# drakes不存在于词向量中
# noras不存在于词向量中
# mols不存在于词向量中
# ashura不存在于词向量中
# hannas不存在于词向量中
# bogdanovichs不存在于词向量中
# goshas不存在于词向量中
# normans不存在于词向量中
# themas不存在于词向量中
# predictablethe不存在于词向量中
# jindabyne不存在于词向量中
# genma不存在于词向量中
# zeffirellis不存在于词向量中
# trex不存在于词向量中
# throughthe不存在于词向量中
# scrooges不存在于词向量中
# peckers不存在于词向量中
# milvertons不存在于词向量中
# funnyand不存在于词向量中
# drivas不存在于词向量中
# creasys不存在于词向量中
# kirks不存在于词向量中
# soi不存在于词向量中
# clampetts不存在于词向量中
# perú不存在于词向量中
# sabretooths不存在于词向量中
# pascow不存在于词向量中
# entertainingthe不存在于词向量中
# sows不存在于词向量中
# unicorn不存在于词向量中
# olan不存在于词向量中
# gores不存在于词向量中
# hollys不存在于词向量中
# wus不存在于词向量中
# iteven不存在于词向量中
# homelessness不存在于词向量中
# doi不存在于词向量中
# beckinsales不存在于词向量中
# starlift不存在于词向量中
# togetheri不存在于词向量中
# 05不存在于词向量中
# locataire不存在于词向量中
# minutesi不存在于词向量中
# ghandi不存在于词向量中
# carons不存在于词向量中
# herren不存在于词向量中
# hilariousi不存在于词向量中
# chalo不存在于词向量中
# 2s不存在于词向量中
# sandras不存在于词向量中
# nivens不存在于词向量中
# comedyi不存在于词向量中
# performancethe不存在于词向量中
# abbys不存在于词向量中
# hermans不存在于词向量中
# coursethe不存在于词向量中
# moneythe不存在于词向量中
# hightower不存在于词向量中
# 1895不存在于词向量中
# thaws不存在于词向量中
# marolla不存在于词向量中
# gades不存在于词向量中
# amitabhs不存在于词向量中
# ninotchka不存在于词向量中
# directorco-writer不存在于词向量中
# cruellas不存在于词向量中
# pransky不存在于词向量中
# yearthe不存在于词向量中
# excellentthe不存在于词向量中
# dibiases不存在于词向量中
# thrillerhorror不存在于词向量中
# todaythe不存在于词向量中
# moronie不存在于词向量中
# reali不存在于词向量中
# sheridans不存在于词向量中
# dayi不存在于词向量中
# shant不存在于词向量中
# evas不存在于词向量中
# detre不存在于词向量中
# directori不存在于词向量中
# dystrophy不存在于词向量中
# wardh不存在于词向量中
# masterpiecethe不存在于词向量中
# haywards不存在于词向量中
# 235:1不存在于词向量中
# iliad不存在于词向量中
# atlantis:不存在于词向量中
# tulipe不存在于词向量中
# itthey不存在于词向量中
# linklaters不存在于词向量中
# ryker不存在于词向量中
# moviefirst不存在于词向量中
# kunderas不存在于词向量中
# wayit不存在于词向量中
# laputa:不存在于词向量中
# wonderfulthe不存在于词向量中
# themso不存在于词向量中
# nightthe不存在于词向量中
# garber不存在于词向量中
# chenoweth不存在于词向量中
# coronets不存在于词向量中
# movienow不存在于词向量中
# filmsbut不存在于词向量中
# elmos不存在于词向量中
# coxs不存在于词向量中
# tarkovskys不存在于词向量中
# paxtons不存在于词向量中
# overthe不存在于词向量中
# otheri不存在于词向量中
# shos不存在于词向量中
# ellens不存在于词向量中
# newbern不存在于词向量中
# tx不存在于词向量中
# tur不存在于词向量中
# classicthe不存在于词向量中
# appolonia不存在于词向量中
# claras不存在于词向量中
# elsei不存在于词向量中
# mathieus不存在于词向量中
# ex-mrs不存在于词向量中
# filmfirst不存在于词向量中
# sothe不存在于词向量中
# sascha不存在于词向量中
# clarkes不存在于词向量中
# boormans不存在于词向量中
# $250000不存在于词向量中
# mums不存在于词向量中
# crimethe不存在于词向量中
# airlift不存在于词向量中
# $50000不存在于词向量中
# approx不存在于词向量中
# 247不存在于词向量中
# filmnow不存在于词向量中
# potters不存在于词向量中
# endingthe不存在于词向量中
# denzels不存在于词向量中
# motherthe不存在于词向量中
# peoplei不存在于词向量中
# colombo不存在于词向量中
# lewtons不存在于词向量中
# chongs不存在于词向量中
# atthe不存在于词向量中
# chavezs不存在于词向量中
# sorter不存在于词向量中
# youif不存在于词向量中
# watchand不存在于词向量中
# herethis不存在于词向量中
# ownthe不存在于词向量中
# ustinovs不存在于词向量中
# hartnetts不存在于词向量中
# caspers不存在于词向量中
# paulas不存在于词向量中
# daves不存在于词向量中
# seeing!不存在于词向量中
# incomprehensibility不存在于词向量中
# haims不存在于词向量中
# springers不存在于词向量中
# himselfi不存在于词向量中
# usthe不存在于词向量中
# kolchaks不存在于词向量中
# gordone不存在于词向量中
# wymer不存在于词向量中
# finneys不存在于词向量中
# elizabeths不存在于词向量中
# askeys不存在于词向量中
# btas不存在于词向量中
# onand不存在于词向量中
# lateri不存在于词向量中
# beban不存在于词向量中
# annoyingthe不存在于词向量中
# elsethe不存在于词向量中
# kriemhilds不存在于词向量中
# onebut不存在于词向量中
# itwell不存在于词向量中
# characteri不存在于词向量中
# dandys不存在于词向量中
# insteadthe不存在于词向量中
# colonels不存在于词向量中
# mcenroe不存在于词向量中
# chomskys不存在于词向量中
# alexanders不存在于词向量中
# wayand不存在于词向量中
# jouissance不存在于词向量中
# haenel不存在于词向量中
# greati不存在于词向量中
# germanys不存在于词向量中
# zhu不存在于词向量中
# costners不存在于词向量中
# hadleys不存在于词向量中
# singletons不存在于词向量中
# mildreds不存在于词向量中
# coolio不存在于词向量中
# alvins不存在于词向量中
# contra不存在于词向量中
# madei不存在于词向量中
# mine!不存在于词向量中
# goldblums不存在于词向量中
# mole-men不存在于词向量中
# ridiculousthe不存在于词向量中
# malones不存在于词向量中
# solvang不存在于词向量中
# whythe不存在于词向量中
# mabuse不存在于词向量中
# downthe不存在于词向量中
# rostov不存在于词向量中
# arethe不存在于词向量中
# waltons不存在于词向量中
# pepi不存在于词向量中
# youthis不存在于词向量中
# laterthe不存在于词向量中
# spartacus不存在于词向量中
# ndour不存在于词向量中
# dooleys不存在于词向量中
# movieas不存在于词向量中
# shinobi不存在于词向量中
# claires不存在于词向量中
# stevensons不存在于词向量中
# womenthe不存在于词向量中
# kikis不存在于词向量中
# bavas不存在于词向量中
# feinstones不存在于词向量中
# kapoors不存在于词向量中
# nextthe不存在于词向量中
# lenas不存在于词向量中
# onemy不存在于词向量中
# kabei不存在于词向量中
# freds不存在于词向量中
# mockingbird不存在于词向量中
# flickthe不存在于词向量中
# sammos不存在于词向量中
# sleepthe不存在于词向量中
# meow不存在于词向量中
# dir不存在于词向量中
# checkpoints不存在于词向量中
# syberbergs不存在于词向量中
# mustnt不存在于词向量中
# redfords不存在于词向量中
# jobthe不存在于词向量中
# moviefor不存在于词向量中
# giovannas不存在于词向量中
# timeas不存在于词向量中
# pyewacket不存在于词向量中
# himbut不存在于词向量中
# rouges不存在于词向量中
# ow不存在于词向量中
# corleones不存在于词向量中
# bladerunner不存在于词向量中
# situationthe不存在于词向量中
# alta不存在于词向量中
# trainor不存在于词向量中
# itnow不存在于词向量中
# 06不存在于词向量中
# homicide:不存在于词向量中
# **12不存在于词向量中
# thisand不存在于词向量中
# spoorloos不存在于词向量中
# awaythe不存在于词向量中
# moviesand不存在于词向量中
# ravine不存在于词向量中
# holmess不存在于词向量中
# hungs不存在于词向量中
# outit不存在于词向量中
# minnellis不存在于词向量中
# marleen不存在于词向量中
# sweid不存在于词向量中
# nguyen不存在于词向量中
# anthonys不存在于词向量中
# berkeleys不存在于词向量中
# willys不存在于词向量中
# themif不存在于词向量中
# ligabue不存在于词向量中
# allin不存在于词向量中
# kordas不存在于词向量中
# wastrel不存在于词向量中
# hazlehurst不存在于词向量中
# mcdiarmid不存在于词向量中
# faubourg不存在于词向量中
# genova不存在于词向量中
# travail不存在于词向量中
# davidtz不存在于词向量中
# pharaohs不存在于词向量中
# fitzgeralds不存在于词向量中
# timebut不存在于词向量中
# goodbad不存在于词向量中
# misha不存在于词向量中
# thatand不存在于词向量中
# poppa不存在于词向量中
# mid-60s不存在于词向量中
# cantillana不存在于词向量中
# ouch不存在于词向量中
# salaam-e-ishq不存在于词向量中
# cunninghams不存在于词向量中
# myrtles不存在于词向量中
# exterminators不存在于词向量中
# neer-do-well不存在于词向量中
# fly-fishing不存在于词向量中
# comstock不存在于词向量中
# nuyoricans不存在于词向量中
# dabo不存在于词向量中
# ieks不存在于词向量中
# mccoys不存在于词向量中
# bakes不存在于词向量中
# numar不存在于词向量中
# harriss不存在于词向量中
# stettner不存在于词向量中
# b:tas不存在于词向量中
# barbaras不存在于词向量中
# hinduism不存在于词向量中
# bradburys不存在于词向量中
# gurnemanz不存在于词向量中
# 4510不存在于词向量中
# lommels不存在于词向量中
# 1983s不存在于词向量中
# phibes不存在于词向量中
# vadis不存在于词向量中
# sorvinos不存在于词向量中
# bueller不存在于词向量中
# fallwell不存在于词向量中
# waterworld不存在于词向量中
# lous不存在于词向量中
# nowthis不存在于词向量中
# seethe不存在于词向量中
# pons不存在于词向量中
# storiesthe不存在于词向量中
# storyone不存在于词向量中
# bethis不存在于词向量中
# stuffthe不存在于词向量中
# marshalls不存在于词向量中
# workit不存在于词向量中
# likei不存在于词向量中
# levants不存在于词向量中
# lifeand不存在于词向量中
# palances不存在于词向量中
# saras不存在于词向量中
# wongs不存在于词向量中
# linethe不存在于词向量中
# lady!不存在于词向量中
# lage不存在于词向量中
# pyuns不存在于词向量中
# bedi不存在于词向量中
# dvdi不存在于词向量中
# horriblethe不存在于词向量中
# actingand不存在于词向量中
# stans不存在于词向量中
# platos不存在于词向量中
# morei不存在于词向量中
# laughthe不存在于词向量中
# interestingthis不存在于词向量中
# momentthe不存在于词向量中
# elviss不存在于词向量中
# prairies不存在于词向量中
# itmy不存在于词向量中
# coppolas不存在于词向量中
# timesin不存在于词向量中
# tiempo不存在于词向量中
# turners不存在于词向量中
# salems不存在于词向量中
# centurythe不存在于词向量中
# moviemost不存在于词向量中
# ofthis不存在于词向量中
# violencethe不存在于词向量中
# meas不存在于词向量中
# wellits不存在于词向量中
# agethe不存在于词向量中
# quantrill不存在于词向量中
# belaney不存在于词向量中
# carusos不存在于词向量中
# martindale不存在于词向量中
# $25000不存在于词向量中
# actionthe不存在于词向量中
# trents不存在于词向量中
# casti不存在于词向量中
# iswhat不存在于词向量中
# silverware不存在于词向量中
# gft不存在于词向量中
# fawcetts不存在于词向量中
# momentsbut不存在于词向量中
# upbut不存在于词向量中
# brashears不存在于词向量中
# courtland不存在于词向量中
# deadthe不存在于词向量中
# stupidthe不存在于词向量中
# tora不存在于词向量中
# infinitum不存在于词向量中
# wasit不存在于词向量中
# goodin不存在于词向量中
# thatch不存在于词向量中
# volckmans不存在于词向量中
# caracas不存在于词向量中
# roedel不存在于词向量中
# bibles不存在于词向量中
# nowthe不存在于词向量中
# ahista不存在于词向量中
# twothe不存在于词向量中
# charactersit不存在于词向量中
# badthis不存在于词向量中
# schwartzmans不存在于词向量中
# betterthis不存在于词向量中
# decors不存在于词向量中
# finally!不存在于词向量中
# audiards不存在于词向量中
# shelleys不存在于词向量中
# funnythis不存在于词向量中
# canyons不存在于词向量中
# poorthe不存在于词向量中
# itat不存在于词向量中
# directorthe不存在于词向量中
# subjectthe不存在于词向量中
# stupidi不存在于词向量中
# buttgereits不存在于词向量中
# fitzs不存在于词向量中
# antitrust不存在于词向量中
# frownland不存在于词向量中
# toshi不存在于词向量中
# ringside不存在于词向量中
# filmwhich不存在于词向量中
# youin不存在于词向量中
# isits不存在于词向量中
# rookies不存在于词向量中
# verger不存在于词向量中
# gussie不存在于词向量中
# slaters不存在于词向量中
# aphrodite不存在于词向量中
# ha-ha不存在于词向量中
# carnality不存在于词向量中
# kinnears不存在于词向量中
# demmes不存在于词向量中
# itthats不存在于词向量中
# poor!不存在于词向量中
# grandmas不存在于词向量中
# sub-zero不存在于词向量中
# iswas不存在于词向量中
# inand不存在于词向量中
# 60searly不存在于词向量中
# ecclestone不存在于词向量中
# fluegel不存在于词向量中
# wwes不存在于词向量中
# peopleand不存在于词向量中
# yearsi不存在于词向量中
# losti不存在于词向量中
# filmall不存在于词向量中
# machi不存在于词向量中
# stiflers不存在于词向量中
# shiner不存在于词向量中
# materialthe不存在于词向量中
# thatits不存在于词向量中
# backi不存在于词向量中
# bromell不存在于词向量中
# cest不存在于词向量中
# 02不存在于词向量中
# farnsworths不存在于词向量中
# hiltz不存在于词向量中
# zapatti不存在于词向量中
# toros不存在于词向量中
# themall不存在于词向量中
# itwhen不存在于词向量中
# herthis不存在于词向量中
# **possible不存在于词向量中
# shemps不存在于词向量中
# brideless不存在于词向量中
# bestworst不存在于词向量中
# 5ive不存在于词向量中
# chahines不存在于词向量中
# anotherthe不存在于词向量中
# movieon不存在于词向量中
# vampires:不存在于词向量中
# filmsits不存在于词向量中
# goldsmiths不存在于词向量中
# trumans不存在于词向量中
# shirleys不存在于词向量中
# shit不存在于词向量中
# bradys不存在于词向量中
# two-parter不存在于词向量中
# understandthe不存在于词向量中
# moviewhen不存在于词向量中
# scolas不存在于词向量中
# kramers不存在于词向量中
# frwl不存在于词向量中
# laughsthe不存在于词向量中
# choule不存在于词向量中
# ratsos不存在于词向量中
# cinemathis不存在于词向量中
# ariels不存在于词向量中
# late-60s不存在于词向量中
# cathryn不存在于词向量中
# unfaithfulness不存在于词向量中
# debenning不存在于词向量中
# mcandrew不存在于词向量中
# itselfthis不存在于词向量中
# awayi不存在于词向量中
# productionthe不存在于词向量中
# guythe不存在于词向量中
# wrestlemanias不存在于词向量中
# :=8p不存在于词向量中
# tremayne不存在于词向量中
# cinemagic不存在于词向量中
# korsmo不存在于词向量中
# themand不存在于词向量中
# peopleif不存在于词向量中
# scenethe不存在于词向量中
# goodoverall不存在于词向量中
# horrorgore不存在于词向量中
# kusama不存在于词向量中
# yvelines不存在于词向量中
# tonalities不存在于词向量中
# effectsi不存在于词向量中
# rounders不存在于词向量中
# madagascar不存在于词向量中
# steppers不存在于词向量中
# filmim不存在于词向量中
# redrum不存在于词向量中
# chestnuts不存在于词向量中
# blairs不存在于词向量中
# farscape不存在于词向量中
# itvery不存在于词向量中
# garbagethe不存在于词向量中
# remoteness不存在于词向量中
# shits不存在于词向量中
# placei不存在于词向量中
# mastersons不存在于词向量中
# patheticthe不存在于词向量中
# bachs不存在于词向量中
# greystoke不存在于词向量中
# see!!!不存在于词向量中
# lv1不存在于词向量中
# watsons不存在于词向量中
# italys不存在于词向量中
# levinsons不存在于词向量中
# fontaines不存在于词向量中
# salmans不存在于词向量中
# firestarter不存在于词向量中
# yearsbut不存在于词向量中
# film1不存在于词向量中
# paedophilia不存在于词向量中
# downi不存在于词向量中
# uh-huh不存在于词向量中
# gentlemans不存在于词向量中
# lovin不存在于词向量中
# milligans不存在于词向量中
# joycelyn不存在于词向量中
# burts不存在于词向量中
# namethe不存在于词向量中
# gothe不存在于词向量中
# jariwala不存在于词向量中
# huh!不存在于词向量中
# 60000不存在于词向量中
# stylethe不存在于词向量中
# hornbys不存在于词向量中
# denard不存在于词向量中
# lacan不存在于词向量中
# aboutand不存在于词向量中
# naissance不存在于词向量中
# pieuvres不存在于词向量中
# alland不存在于词向量中
# sukowa不存在于词向量中
# sydows不存在于词向量中
# miryang不存在于词向量中
# warthog不存在于词向量中
# isit不存在于词向量中
# fuquas不存在于词向量中
# publications不存在于词向量中
# alekos不存在于词向量中
# thunderchild不存在于词向量中
# wolfs不存在于词向量中
# againthis不存在于词向量中
# daysthis不存在于词向量中
# filmsit不存在于词向量中
# beerys不存在于词向量中
# hereits不存在于词向量中
# arkins不存在于词向量中
# itlike不存在于词向量中
# thembut不存在于词向量中
# cimarron不存在于词向量中
# gabel不存在于词向量中
# ryecart不存在于词向量中
# dykes不存在于词向量中
# lantana不存在于词向量中
# dietrichs不存在于词向量中
# endit不存在于词向量中
# editingthe不存在于词向量中
# d-war不存在于词向量中
# chirila不存在于词向量中
# chandon不存在于词向量中
# businessthe不存在于词向量中
# swifts不存在于词向量中
# chabrols不存在于词向量中
# thoughthis不存在于词向量中
# shanao不存在于词向量中
# pulps不存在于词向量中
# worldin不存在于词向量中
# flicki不存在于词向量中
# along!不存在于词向量中
# filmoverall不存在于词向量中
# pseudoscience不存在于词向量中
# beit不存在于词向量中
# zombification不存在于词向量中
# ardelean不存在于词向量中
# ideathe不存在于词向量中
# mehbooba不存在于词向量中
# florianes不存在于词向量中
# soweto不存在于词向量中
# diplomacy不存在于词向量中
# actorthe不存在于词向量中
# ismy不存在于词向量中
# murrays不存在于词向量中
# thema不存在于词向量中
# watchingthe不存在于词向量中
# cameramans不存在于词向量中
# monarchs不存在于词向量中
# chandlers不存在于词向量中
# hbos不存在于词向量中
# midlers不存在于词向量中
# tybalt不存在于词向量中
# crowd-pleaser不存在于词向量中
# spagnolo不存在于词向量中
# waterdance不存在于词向量中
# vics不存在于词向量中
# wellingtons不存在于词向量中
# rambos不存在于词向量中
# stolz不存在于词向量中
# coalwood不存在于词向量中
# superstardom不存在于词向量中
# larn不存在于词向量中
# melvilles不存在于词向量中
# badand不存在于词向量中
# societythe不存在于词向量中
# hak不存在于词向量中
# bennetts不存在于词向量中
# zavet不存在于词向量中
# arnies不存在于词向量中
# wauters不存在于词向量中
# rightthis不存在于词向量中
# luján不存在于词向量中
# 30000不存在于词向量中
# munshi不存在于词向量中
# upthis不存在于词向量中
# performancesthe不存在于词向量中
# allbut不存在于词向量中
# bromfield不存在于词向量中
# detat不存在于词向量中
# naudets不存在于词向量中
# dorie不存在于词向量中
# andretti不存在于词向量中
# jasons不存在于词向量中
# hallgren不存在于词向量中
# himmelen不存在于词向量中
# schneiders不存在于词向量中
# altaira不存在于词向量中
# burkina不存在于词向量中
# faso不存在于词向量中
# foxworth不存在于词向量中
# lube不存在于词向量中
# sabus不存在于词向量中
# moes不存在于词向量中
# apposite不存在于词向量中
# cragg不存在于词向量中
# watchif不存在于词向量中
# goodit不存在于词向量中
# matteis不存在于词向量中
# berkowitzs不存在于词向量中
# yetthe不存在于词向量中
# anistons不存在于词向量中
# sincethe不存在于词向量中
# wrongthis不存在于词向量中
# naught不存在于词向量中
# knef不存在于词向量中
# entertainmentthe不存在于词向量中
# peoplethis不存在于词向量中
# wolverines不存在于词向量中
# cq不存在于词向量中
# shepards不存在于词向量中
# bjorlin不存在于词向量中
# surprisethe不存在于词向量中
# gerards不存在于词向量中
# outthere不存在于词向量中
# uks不存在于词向量中
# panaghoy不存在于词向量中
# moviewhat不存在于词向量中
# curtiss不存在于词向量中
# exhibitions不存在于词向量中
# etcthis不存在于词向量中
# junge不存在于词向量中
# mirage不存在于词向量中
# stroh不存在于词向量中
# narsimha不存在于词向量中
# thisa不存在于词向量中
# sensethe不存在于词向量中
# barsi不存在于词向量中
# notebooks不存在于词向量中
# barmans不存在于词向量中
# moviesif不存在于词向量中
# oneills不存在于词向量中
# cronenbergs不存在于词向量中
# sherrys不存在于词向量中
# tchaikovskys不存在于词向量中
# mencias不存在于词向量中
# lloyds不存在于词向量中
# bridgets不存在于词向量中
# huggaland不存在于词向量中
# almodovars不存在于词向量中
# rangi不存在于词向量中
# jennys不存在于词向量中
# fini不存在于词向量中
# pallbearer不存在于词向量中
# 70s80s不存在于词向量中
# youand不存在于词向量中
# julias不存在于词向量中
# $750不存在于词向量中
# camerathe不存在于词向量中
# thurmans不存在于词向量中
# seenit不存在于词向量中
# miraglias不存在于词向量中
# hillyers不存在于词向量中
# gubra不存在于词向量中
# saint-denis不存在于词向量中
# lexs不存在于词向量中
# waysthe不存在于词向量中
# holcomb不存在于词向量中
# soloist不存在于词向量中
# mohawk不存在于词向量中
# itive不存在于词向量中
# 237不存在于词向量中
# shatners不存在于词向量中
# historyi不存在于词向量中
# choco不存在于词向量中
# timberlakes不存在于词向量中
# gasp!不存在于词向量中
# anew不存在于词向量中
# mistakei不存在于词向量中
# earlys不存在于词向量中
# versioni不存在于词向量中
# yousef不存在于词向量中
# dilly不存在于词向量中
# jennas不存在于词向量中
# heyerdahl不存在于词向量中
# anythingi不存在于词向量中
# imamuras不存在于词向量中
# marions不存在于词向量中
# therell不存在于词向量中
# 4-3不存在于词向量中
# noams不存在于词向量中
# agothe不存在于词向量中
# lawrences不存在于词向量中
# boringthe不存在于词向量中
# mexicos不存在于词向量中
# hitoto不存在于词向量中
# tans不存在于词向量中
# gypos不存在于词向量中
# subor不存在于词向量中
# magruder不存在于词向量中
# deads不存在于词向量中
# scorpione不存在于词向量中
# thismovie不存在于词向量中
# careerthe不存在于词向量中
# halprin不存在于词向量中
# laroche不存在于词向量中
# cornillac不存在于词向量中
# rataud不存在于词向量中
# deniss不存在于词向量中
# lohans不存在于词向量中
# lovethis不存在于词向量中
# basingers不存在于词向量中
# artisans不存在于词向量中
# wurb不存在于词向量中
# zomcon不存在于词向量中
# didnt!不存在于词向量中
# sallys不存在于词向量中
# cristinas不存在于词向量中
# pabsts不存在于词向量中
# changs不存在于词向量中
# alls不存在于词向量中
# funnyit不存在于词向量中
# boz不存在于词向量中
# everi不存在于词向量中
# mathesons不存在于词向量中
# cama不存在于词向量中
# gato不存在于词向量中
# rashid不存在于词向量中
# charnier不存在于词向量中
# castorini不存在于词向量中
# vaughns不存在于词向量中
# sheedys不存在于词向量中
# windscreen不存在于词向量中
# remer不存在于词向量中
# missing!不存在于词向量中
# celies不存在于词向量中
# no2不存在于词向量中
# unsinkable不存在于词向量中
# andwell不存在于词向量中
# danas不存在于词向量中
# forthe不存在于词向量中
# neenan不存在于词向量中
# holroyd不存在于词向量中
# dassins不存在于词向量中
# marner不存在于词向量中
# urbaniak不存在于词向量中
# kaun不存在于词向量中
# yall不存在于词向量中
# unforgiven不存在于词向量中
# dellorco不存在于词向量中
# edmunds不存在于词向量中
# barjatyas不存在于词向量中
# takechi不存在于词向量中
# nr不存在于词向量中
# cut!不存在于词向量中
# trampa不存在于词向量中
# trautman不存在于词向量中
# hagars不存在于词向量中
# shinae不存在于词向量中
# 1the不存在于词向量中
# cloudkicker不存在于词向量中
# moneyi不存在于词向量中
# cybersix不存在于词向量中
# ginos不存在于词向量中
# momentsi不存在于词向量中
# wolfes不存在于词向量中
# solent不存在于词向量中
# tets不存在于词向量中
# necroborgs不存在于词向量中
# `queen不存在于词向量中
# vera-ellens不存在于词向量中
# schneebaums不存在于词向量中
# andrés不存在于词向量中
# fulbright不存在于词向量中
# gas!不存在于词向量中
# pyms不存在于词向量中
# crains不存在于词向量中
# donnisons不存在于词向量中
# arzenta不存在于词向量中
# aymeric不存在于词向量中
# mjs不存在于词向量中
# migraines不存在于词向量中
# havethe不存在于词向量中
# coote不存在于词向量中
# hammerhead:不存在于词向量中
# filmvery不存在于词向量中
# pertwees不存在于词向量中
# prez不存在于词向量中
# splat不存在于词向量中
# wangs不存在于词向量中
# culkins不存在于词向量中
# citythe不存在于词向量中
# collettes不存在于词向量中
# fixit不存在于词向量中
# moviehowever不存在于词向量中
# presidente不存在于词向量中
# tutors不存在于词向量中
# non-event不存在于词向量中
# beetlejuice不存在于词向量中
# spradling不存在于词向量中
# masons不存在于词向量中
# 1-2-3不存在于词向量中
# matchthe不存在于词向量中
# girlthe不存在于词向量中
# barrys不存在于词向量中
# scenei不存在于词向量中
# +-不存在于词向量中
# convolutions不存在于词向量中
# entanglement不存在于词向量中
# somethingthe不存在于词向量中
# ariauna不存在于词向量中
# danis不存在于词向量中
# rodneys不存在于词向量中
# gouald不存在于词向量中
# suplexes不存在于词向量中
# himits不存在于词向量中
# plotthis不存在于词向量中
# castros不存在于词向量中
# descendents不存在于词向量中
# timedirector不存在于词向量中
# showthis不存在于词向量中
# f-不存在于词向量中
# proog不存在于词向量中
# hadleyville不存在于词向量中
# roxbury不存在于词向量中
# shortthe不存在于词向量中
# catalan不存在于词向量中
# glenrowan不存在于词向量中
# watchingi不存在于词向量中
# muchif不存在于词向量中
# bernhards不存在于词向量中
# watchi不存在于词向量中
# poms不存在于词向量中
# $12000000不存在于词向量中
# bigs不存在于词向量中
# reveres不存在于词向量中
# eustaches不存在于词向量中
# bolero不存在于词向量中
# fn不存在于词向量中
# periodi不存在于词向量中
# onin不存在于词向量中
# againin不存在于词向量中
# gp不存在于词向量中
# sculptures不存在于词向量中
# uranium不存在于词向量中
# gadar不存在于词向量中
# storyits不存在于词向量中
# workand不存在于词向量中
# madethis不存在于词向量中
# kidsi不存在于词向量中
# renoirs不存在于词向量中
# noland不存在于词向量中
# hara不存在于词向量中
# heroheroine不存在于词向量中
# fois不存在于词向量中
# lettieri不存在于词向量中
# salo不存在于词向量中
# velankar不存在于词向量中
# torturei不存在于词向量中
# tippi不存在于词向量中
# gainey不存在于词向量中
# interestingi不存在于词向量中
# barbarella不存在于词向量中
# goldbergs不存在于词向量中
# groovin不存在于词向量中
# nebula不存在于词向量中
# amazingand不存在于词向量中
# theni不存在于词向量中
# producerdirector不存在于词向量中
# zenias不存在于词向量中
# rozs不存在于词向量中
# okeeffe不存在于词向量中
# cubas不存在于词向量中
# grandpas不存在于词向量中
# joshs不存在于词向量中
# trombone不存在于词向量中
# endingthis不存在于词向量中
# dentistry不存在于词向量中
# brisbane不存在于词向量中
# philanthropist不存在于词向量中
# bethere不存在于词向量中
# audiencei不存在于词向量中
# holms不存在于词向量中
# beenthe不存在于词向量中
# crouses不存在于词向量中
# martys不存在于词向量中
# cuoco不存在于词向量中
# tereza不存在于词向量中
# itafter不存在于词向量中
# akshays不存在于词向量中
# muchit不存在于词向量中
# itone不存在于词向量中
# heorot不存在于词向量中
# muchand不存在于词向量中
# ithowever不存在于词向量中
# endbut不存在于词向量中
# timeso不存在于词向量中
# foleys不存在于词向量中
# dramathe不存在于词向量中
# 1010!不存在于词向量中
# thunderbolt不存在于词向量中
# ladykillers不存在于词向量中
# ofi不存在于词向量中
# liviens不存在于词向量中
# nolans不存在于词向量中
# 07不存在于词向量中
# burgundians不存在于词向量中
# jesters不存在于词向量中
# facei不存在于词向量中
# iton不存在于词向量中
# bernsens不存在于词向量中
# extinguishers不存在于词向量中
# seenthis不存在于词向量中
# lighti不存在于词向量中
# darkheart不存在于词向量中
# beforethis不存在于词向量中
# chriss不存在于词向量中
# anodyne不存在于词向量中
# steeles不存在于词向量中
# pasadena不存在于词向量中
# darc不存在于词向量中
# wiseman不存在于词向量中
# scoops不存在于词向量中
# watermans不存在于词向量中
# facilitator不存在于词向量中
# roomthe不存在于词向量中
# alexandres不存在于词向量中
# raina不存在于词向量中
# nazgul不存在于词向量中
# fancier不存在于词向量中
# waya不存在于词向量中
# filmto不存在于词向量中
# inhe不存在于词向量中
# conchata不存在于词向量中
# twos不存在于词向量中
# arisen不存在于词向量中
# top-quality不存在于词向量中
# fidos不存在于词向量中
# happenedi不存在于词向量中
# lifeas不存在于词向量中
# dornwinkle不存在于词向量中
# http:wwwpetitiononlinecomgh1215petitionhtml不存在于词向量中
# tysons不存在于词向量中
# 713不存在于词向量中
# showsthe不存在于词向量中
# jehovahs不存在于词向量中
# pias不存在于词向量中
# yoshinaga不存在于词向量中
# mauricio不存在于词向量中
# narcolepsy不存在于词向量中
# missi不存在于词向量中
# directorthis不存在于词向量中
# bards不存在于词向量中
# yeari不存在于词向量中
# zimmers不存在于词向量中
# meds不存在于词向量中
# aarons不存在于词向量中
# withi不存在于词向量中
# gornick不存在于词向量中
# hyser不存在于词向量中
# likethe不存在于词向量中
# thingthis不存在于词向量中
# himso不存在于词向量中
# tommys不存在于词向量中
# katsus不存在于词向量中
# artemisias不存在于词向量中
# amati不存在于词向量中
# owni不存在于词向量中
# werners不存在于词向量中
# setthe不存在于词向量中
# fl不存在于词向量中
# storyfor不存在于词向量中
# actingthis不存在于词向量中
# digicorps不存在于词向量中
# somethingthis不存在于词向量中
# mommys不存在于词向量中
# alois不存在于词向量中
# wella不存在于词向量中
# site!不存在于词向量中
# earlierthe不存在于词向量中
# matterthe不存在于词向量中
# tuileries不存在于词向量中
# dothis不存在于词向量中
# ebsen不存在于词向量中
# fani不存在于词向量中
# blackwhite不存在于词向量中
# directioni不存在于词向量中
# allim不存在于词向量中
# tolstoys不存在于词向量中
# notif不存在于词向量中
# deannas不存在于词向量中
# isbut不存在于词向量中
# othellos不存在于词向量中
# luminescence不存在于词向量中
# thunderball不存在于词向量中
# successthe不存在于词向量中
# navel-gazing不存在于词向量中
# altair不存在于词向量中
# levelthe不存在于词向量中
# kine不存在于词向量中
# hubbys不存在于词向量中
# pratfall不存在于词向量中
# yodas不存在于词向量中
# wendts不存在于词向量中
# meretricious不存在于词向量中
# sequencethe不存在于词向量中
# thatafter不存在于词向量中
# curlys不存在于词向量中
# watchtower不存在于词向量中
# eitherits不存在于词向量中
# perspectivethe不存在于词向量中
# mid-30s不存在于词向量中
# casei不存在于词向量中
# itid不存在于词向量中
# rebar不存在于词向量中
# thesethe不存在于词向量中
# itnot不存在于词向量中
# acorn不存在于词向量中
# directionthe不存在于词向量中
# bungalow不存在于词向量中
# mahers不存在于词向量中
# scenesthis不存在于词向量中
# movieshe不存在于词向量中
# obrian不存在于词向量中
# preacherman不存在于词向量中
# write-off不存在于词向量中
# grangers不存在于词向量中
# juliana不存在于词向量中
# catscratch不存在于词向量中
# actinga不存在于词向量中
# hutson不存在于词向量中
# belas不存在于词向量中
# gummo不存在于词向量中
# gruel不存在于词向量中
# scotlands不存在于词向量中
# evelyns不存在于词向量中
# murdersthe不存在于词向量中
# onit不存在于词向量中
# wayif不存在于词向量中
# `mr不存在于词向量中
# gonethe不存在于词向量中
# wargames:不存在于词向量中
# who-dunnit不存在于词向量中
# grandsons不存在于词向量中
# moreira不存在于词向量中
# non-existant不存在于词向量中
# roachs不存在于词向量中
# huntingdon不存在于词向量中
# moviewith不存在于词向量中
# homoeroticism不存在于词向量中
# itsome不存在于词向量中
# moviesso不存在于词向量中
# kol不存在于词向量中
# catwalk不存在于词向量中
# whoopee不存在于词向量中
# worldas不存在于词向量中
# bullhorn不存在于词向量中
# napoli不存在于词向量中
# fenwick不存在于词向量中
# thatso不存在于词向量中
# knowthis不存在于词向量中
# movieyes不存在于词向量中
# sinclairs不存在于词向量中
# calvins不存在于词向量中
# vette不存在于词向量中
# ick不存在于词向量中
# southampton不存在于词向量中
# schepisi不存在于词向量中
# potentialthe不存在于词向量中
# olivers不存在于词向量中
# levene不存在于词向量中
# movienot不存在于词向量中
# beforei不存在于词向量中
# catherines不存在于词向量中
# habitats不存在于词向量中
# delias不存在于词向量中
# pavarottis不存在于词向量中
# db不存在于词向量中
# ashleys不存在于词向量中
# bookthe不存在于词向量中
# anotherthis不存在于词向量中
# matts不存在于词向量中
# themwhat不存在于词向量中
# abstractions不存在于词向量中
# rivera不存在于词向量中
# tvthe不存在于词向量中
# hypercube不存在于词向量中
# werewolfs不存在于词向量中
# interestingand不存在于词向量中
# lams不存在于词向量中
# riedelsheimer不存在于词向量中
# shahids不存在于词向量中
# chancethe不存在于词向量中
# cullen不存在于词向量中
# livin不存在于词向量中
# leonoras不存在于词向量中
# $250不存在于词向量中
# spiritualism不存在于词向量中
# kattans不存在于词向量中
# timetable不存在于词向量中
# tourneurs不存在于词向量中
# artthe不存在于词向量中
# itno不存在于词向量中
# dcom不存在于词向量中
# musicthis不存在于词向量中
# ddt不存在于词向量中
# amen不存在于词向量中
# realismthe不存在于词向量中
# filmoh不存在于词向量中
# vampiros不存在于词向量中
# prestons不存在于词向量中
# milford不存在于词向量中
# trotter不存在于词向量中
# sergius不存在于词向量中
# enemys不存在于词向量中
# pazus不存在于词向量中
# monasterys不存在于词向量中
# childthis不存在于词向量中
# windman不存在于词向量中
# jobi不存在于词向量中
# lorettas不存在于词向量中
# bauraki不存在于词向量中
# eg:不存在于词向量中
# natch不存在于词向量中
# durantes不存在于词向量中
# dafoes不存在于词向量中
# careys不存在于词向量中
# welchs不存在于词向量中
# bluths不存在于词向量中
# shae不存在于词向量中
# barneys不存在于词向量中
# nathans不存在于词向量中
# himherself不存在于词向量中
# pointthis不存在于词向量中
# cinematograph不存在于词向量中
# doers不存在于词向量中
# brideshead不存在于词向量中
# oaters不存在于词向量中
# blachere不存在于词向量中
# bulldozers不存在于词向量中
# monteith不存在于词向量中
# haack不存在于词向量中
# curtizs不存在于词向量中
# mules不存在于词向量中
# dansu不存在于词向量中
# :-d不存在于词向量中
# pelletier不存在于词向量中
# goin不存在于词向量中
# ploti不存在于词向量中
# aroundi不存在于词向量中
# goodtimes不存在于词向量中
# frollo不存在于词向量中
# dresslers不存在于词向量中
# etcso不存在于词向量中
# cheang不存在于词向量中
# tarrs不存在于词向量中
# budgetthe不存在于词向量中
# word!不存在于词向量中
# spiers不存在于词向量中
# mongolia不存在于词向量中
# writerthe不存在于词向量中
# vadas不存在于词向量中
# itof不存在于词向量中
# overhyped不存在于词向量中
# linderby不存在于词向量中
# motherdaughter不存在于词向量中
# alsoi不存在于词向量中
# playoffs不存在于词向量中
# bacalls不存在于词向量中
# worsei不存在于词向量中
# scenebut不存在于词向量中
# piovani不存在于词向量中
# marjories不存在于词向量中
# crandall不存在于词向量中
# greatand不存在于词向量中
# ferraris不存在于词向量中
# worldthis不存在于词向量中
# alberta不存在于词向量中
# itwith不存在于词向量中
# storyas不存在于词向量中
# nixons不存在于词向量中
# powerthe不存在于词向量中
# rothschild不存在于词向量中
# vidors不存在于词向量中
# peptides不存在于词向量中
# pryors不存在于词向量中
# linfield不存在于词向量中
# schrieber不存在于词向量中
# phoenixs不存在于词向量中
# boen不存在于词向量中
# show-off不存在于词向量中
# gauris不存在于词向量中
# mckees不存在于词向量中
# rushton不存在于词向量中
# beaute不存在于词向量中
# 1894不存在于词向量中
# mcgavins不存在于词向量中
# isotopes不存在于词向量中
# andies不存在于词向量中
# ferrells不存在于词向量中
# iturbis不存在于词向量中
# penry-jones不存在于词向量中
# paramilitaries不存在于词向量中
# didt不存在于词向量中
# repairman不存在于词向量中
# rheostatics不存在于词向量中
# gorethe不存在于词向量中
# headthe不存在于词向量中
# erathe不存在于词向量中
# briny不存在于词向量中
# thatin不存在于词向量中
# dangerfields不存在于词向量中
# chabon不存在于词向量中
# rainmaker不存在于词向量中
# housethe不存在于词向量中
# hensons不存在于词向量中
# tadashis不存在于词向量中
# noahs不存在于词向量中
# amenabars不存在于词向量中
# tesis不存在于词向量中
# dillons不存在于词向量中
# ginas不存在于词向量中
# heckerling不存在于词向量中
# meif不存在于词向量中
# worsethis不存在于词向量中
# gokbakar不存在于词向量中
# siv不存在于词向量中
# sammis不存在于词向量中
# beethovens不存在于词向量中
# pace!不存在于词向量中
# ak-47不存在于词向量中
# hepton不存在于词向量中
# borge不存在于词向量中
# jew!不存在于词向量中
# jesuss不存在于词向量中
# republics不存在于词向量中
# showroom不存在于词向量中
# jakub不存在于词向量中
# dialoguethe不存在于词向量中
# es不存在于词向量中
# etzel不存在于词向量中
# seachd不存在于词向量中
# seriouslythe不存在于词向量中
# videoi不存在于词向量中
# asimovs不存在于词向量中
# floyds不存在于词向量中
# disappointedi不存在于词向量中
# inas不存在于词向量中
# konvitz不存在于词向量中
# buddys不存在于词向量中
# wrights不存在于词向量中
# godfathers不存在于词向量中
# hauntings不存在于词向量中
# *may不存在于词向量中
# filmwith不存在于词向量中
# hickey不存在于词向量中
# allif不存在于词向量中
# playthe不存在于词向量中
# amputee不存在于词向量中
# zuckerman不存在于词向量中
# launius不存在于词向量中
# quintana不存在于词向量中
# malthe不存在于词向量中
# schaffer不存在于词向量中
# capras不存在于词向量中
# towelhead不存在于词向量中
# interestthe不存在于词向量中
# enoughthe不存在于词向量中
# abigails不存在于词向量中
# kroko不存在于词向量中
# filmby不存在于词向量中
# talentthe不存在于词向量中
# everythingthe不存在于词向量中
# watchedthe不存在于词向量中
# forrests不存在于词向量中
# coincidently不存在于词向量中
# scarman不存在于词向量中
# lukass不存在于词向量中
# 70si不存在于词向量中
# malamud不存在于词向量中
# homefront不存在于词向量中
# kandice不存在于词向量中
# moroder不存在于词向量中
# mats不存在于词向量中
# shekhars不存在于词向量中
# ambassadors不存在于词向量中
# absurdness不存在于词向量中
# slugs:不存在于词向量中
# bushs不存在于词向量中
# lamia不存在于词向量中
# merediths不存在于词向量中
# insp不存在于词向量中
# etcit不存在于词向量中
# så不存在于词向量中
# zealanders不存在于词向量中
# yakitate!不存在于词向量中
# goould不存在于词向量中
# js不存在于词向量中
# glickenhaus不存在于词向量中
# cardos不存在于词向量中
# barnett不存在于词向量中
# hugsy不存在于词向量中
# piedras不存在于词向量中
# cervera不存在于词向量中
# flawsthe不存在于词向量中
# hipness不存在于词向量中
# lifebut不存在于词向量中
# finishthe不存在于词向量中
# dreama不存在于词向量中
# duchovnys不存在于词向量中
# mostels不存在于词向量中
# gaillardia不存在于词向量中
# flux不存在于词向量中
# callan不存在于词向量中
# adieu不存在于词向量中
# alzheimers不存在于词向量中
# khakee不存在于词向量中
# mitchells不存在于词向量中
# genn不存在于词向量中
# chastened不存在于词向量中
# rc不存在于词向量中
# kelada不存在于词向量中
# trumpeter不存在于词向量中
# mistakethe不存在于词向量中
# gabriels不存在于词向量中
# sadies不存在于词向量中
# opinioni不存在于词向量中
# yore不存在于词向量中
# tykwers不存在于词向量中
# victoires不存在于词向量中
# père-lachaise不存在于词向量中
# friendless不存在于词向量中
# loessers不存在于词向量中
# usas不存在于词向量中
# mrlincoln不存在于词向量中
# videothe不存在于词向量中
# ge999不存在于词向量中
# chehs不存在于词向量中
# bangladesh不存在于词向量中
# disappointedthis不存在于词向量中
# filmthat不存在于词向量中
# mallepa不存在于词向量中
# madeand不存在于词向量中
# witherspoons不存在于词向量中
# otooles不存在于词向量中
# scripti不存在于词向量中
# charactersas不存在于词向量中
# geisel不存在于词向量中
# winslets不存在于词向量中
# lifeone不存在于词向量中
# raffin不存在于词向量中
# trelkovskys不存在于词向量中
# brilliantthe不存在于词向量中
# eitherthis不存在于词向量中
# starck不存在于词向量中
# film!!!!不存在于词向量中
# bohlen不存在于词向量中
# outin不存在于词向量中
# ruge不存在于词向量中
# deans不存在于词向量中
# 4-bad不存在于词向量中
# solino不存在于词向量中
# thrush不存在于词向量中
# heflins不存在于词向量中
# amandas不存在于词向量中
# uranus不存在于词向量中
# timesand不存在于词向量中
# herand不存在于词向量中
# centurys不存在于词向量中
# boththe不存在于词向量中
# kagan不存在于词向量中
# personi不存在于词向量中
# thefts不存在于词向量中
# radiofreccia不存在于词向量中
# aboriginals不存在于词向量中
# justins不存在于词向量中
# upand不存在于词向量中
# rainbeaux不存在于词向量中
# aragami不存在于词向量中
# meh不存在于词向量中
# spoonful不存在于词向量中
# 1s不存在于词向量中
# ajas不存在于词向量中
# margarete不存在于词向量中
# hassie不存在于词向量中
# brendon不存在于词向量中
# molla不存在于词向量中
# klaws不存在于词向量中
# townsends不存在于词向量中
# lessthe不存在于词向量中
# newell不存在于词向量中
# saskatchewan不存在于词向量中
# haarman不存在于词向量中
# cuckold不存在于词向量中
# cuarón不存在于词向量中
# melchior不存在于词向量中
# coixet不存在于词向量中
# directorproducer不存在于词向量中
# hereand不存在于词向量中
# filmhowever不存在于词向量中
# valcos不存在于词向量中
# schepisis不存在于词向量中
# watling不存在于词向量中
# dammit不存在于词向量中
# genoa不存在于词向量中
# hereafter不存在于词向量中
# rolethis不存在于词向量中
# **spoilers**不存在于词向量中
# tingler不存在于词向量中
# bannings不存在于词向量中
# stirbas不存在于词向量中
# neatness不存在于词向量中
# asgard不存在于词向量中
# wtf!不存在于词向量中
# gnatpole不存在于词向量中
# craigs不存在于词向量中
# lancasters不存在于词向量中
# s2t不存在于词向量中
# hanlon不存在于词向量中
# isand不存在于词向量中
# chewie不存在于词向量中
# wellyou不存在于词向量中
# snore-fest不存在于词向量中
# voyagers不存在于词向量中
# cpt不存在于词向量中
# aswell不存在于词向量中
# gérald不存在于词向量中
# laudenbach不存在于词向量中
# christophers不存在于词向量中
# cosimo不存在于词向量中
# carrys不存在于词向量中
# alonethe不存在于词向量中
# klute不存在于词向量中
# mindi不存在于词向量中
# bucktown不存在于词向量中
# domergues不存在于词向量中
# domini不存在于词向量中
# showand不存在于词向量中
# burlinson不存在于词向量中
# undecipherable不存在于词向量中
# dibley不存在于词向量中
# hawns不存在于词向量中
# hackmans不存在于词向量中
# aro不存在于词向量中
# dumroo不存在于词向量中
# richardsons不存在于词向量中
# ermine不存在于词向量中
# englebert不存在于词向量中
# woah不存在于词向量中
# emotionthe不存在于词向量中
# fp1不存在于词向量中
# cassies不存在于词向量中
# suo不存在于词向量中
# hereit不存在于词向量中
# barek不存在于词向量中
# loti不存在于词向量中
# williamss不存在于词向量中
# ulees不存在于词向量中
# rubys不存在于词向量中
# saboteur不存在于词向量中
# raimy不存在于词向量中
# talosians不存在于词向量中
# richies不存在于词向量中
# mir不存在于词向量中
# dietrichson不存在于词向量中
# tristans不存在于词向量中
# hateable不存在于词向量中
# horrorthe不存在于词向量中
# rookers不存在于词向量中
# climaxthis不存在于词向量中
# razzle-dazzle不存在于词向量中
# hadass不存在于词向量中
# consummated不存在于词向量中
# langlaise不存在于词向量中
# gingers不存在于词向量中
# roebuck不存在于词向量中
# testa不存在于词向量中
# eikenberry不存在于词向量中
# fedja不存在于词向量中
# titanics不存在于词向量中
# narasimha不存在于词向量中
# wowi不存在于词向量中
# demonstrative不存在于词向量中
# eadie不存在于词向量中
# tgif不存在于词向量中
# nadji不存在于词向量中
# burrs不存在于词向量中
# annemarie不存在于词向量中
# reflexes不存在于词向量中
# trenchcoat不存在于词向量中
# mensonges不存在于词向量中
# antonella不存在于词向量中
# minot不存在于词向量中
# bambis不存在于词向量中
# ramallo不存在于词向量中
# donofrio不存在于词向量中
# itwho不存在于词向量中
# amis不存在于词向量中
# watership不存在于词向量中
# charactersthis不存在于词向量中
# iswell不存在于词向量中
# veils不存在于词向量中
# lengles不存在于词向量中
# bilious不存在于词向量中
# madea不存在于词向量中
# lockes不存在于词向量中
# dkd不存在于词向量中
# donlan不存在于词向量中
# joyces不存在于词向量中
# mean!不存在于词向量中
# actordirector不存在于词向量中
# gymnasium不存在于词向量中
# torrances不存在于词向量中
# anands不存在于词向量中
# mechs不存在于词向量中
# tasuiev不存在于词向量中
# petiots不存在于词向量中
# thatthere不存在于词向量中
# cias不存在于词向量中
# akhras不存在于词向量中
# thuy不存在于词向量中
# irans不存在于词向量中
# !!!!!!!!不存在于词向量中
# tftc不存在于词向量中
# gr不存在于词向量中
# newcombes不存在于词向量中
# rivendell不存在于词向量中
# birney不存在于词向量中
# cabals不存在于词向量中
# tentitle不存在于词向量中
# molinas不存在于词向量中
# mcnicol不存在于词向量中
# carradines不存在于词向量中
# randle不存在于词向量中
# 10the不存在于词向量中
# meand不存在于词向量中
# cothk不存在于词向量中
# parn不存在于词向量中
# onesthe不存在于词向量中
# bregana不存在于词向量中
# antonius不存在于词向量中
# herethere不存在于词向量中
# cassavettess不存在于词向量中
# yoshida不存在于词向量中
# pvt不存在于词向量中
# doa不存在于词向量中
# sin-eater不存在于词向量中
# acs不存在于词向量中
# chomet不存在于词向量中
# loulou不存在于词向量中
# kolchak:不存在于词向量中
# okeefe不存在于词向量中
# turaqistan不存在于词向量中
# 666:不存在于词向量中
# hupperts不存在于词向量中
# tel-aviv不存在于词向量中
# summersisle不存在于词向量中
# deth不存在于词向量中
# yanos不存在于词向量中
# yolande不存在于词向量中
# soll不存在于词向量中
# gulfax不存在于词向量中
# frankie-boy不存在于词向量中
# byrons不存在于词向量中
# emigrant不存在于词向量中
# don-del-oro不存在于词向量中
# kazakos不存在于词向量中
# trackersjourneymen!!不存在于词向量中
# kennicut不存在于词向量中

# %%
print("train data shape: {}".format(data.trainReviews.shape))
print("train label shape: {}".format(data.trainLabels.shape))
print("eval data shape: {}".format(data.evalReviews.shape))
# Out:
# train data shape: (20000, 200)
# train label shape: (20000, 1)
# eval data shape: (5000, 200)

# %% [markdown]
# ## 生成batch数据集
#
# 　　采用生成器的形式向模型输入batch数据集，（生成器可以避免将所有的数据加入到内存中）

# %%
# 输出batch数据集

def nextBatch(x, y, batchSize):
        '''
         生成batch数据集，用生成器的方式输出
        
        :param x:      list    
        :param y:      list    
        :param batchSize:      int    
        :return: 
            batchX        nnumpy array
            batchY        nnumpy array
            
        '''
    
        perm = np.arange(len(x))
        np.random.shuffle(perm)
        x = x[perm]
        y = y[perm]
        
        numBatches = len(x) // batchSize

        for i in range(numBatches):
            start = i * batchSize
            end = start + batchSize
            batchX = np.array(x[start: end], dtype="int64")
            batchY = np.array(y[start: end], dtype="float32")
            
            yield batchX, batchY

# %% [markdown]
# ## Bi-LSTM + Attention模型

# %%
# 构建模型
class BiLSTMAttention(object):
    """
    Text CNN 用于文本分类
    """
    def __init__(self, config, wordEmbedding):

        # 定义模型的输入
        self.inputX = tf.placeholder(tf.int32, [None, config.sequenceLength], name="inputX")
        self.inputY = tf.placeholder(tf.float32, [None, 1], name="inputY")
        
        self.dropoutKeepProb = tf.placeholder(tf.float32, name="dropoutKeepProb")
        
        # 定义l2损失
        l2Loss = tf.constant(0.0)
        
        # 词嵌入层
        with tf.name_scope("embedding"):

            # 利用预训练的词向量初始化词嵌入矩阵
            self.W = tf.Variable(tf.cast(wordEmbedding, dtype=tf.float32, name="word2vec") ,name="W")
            # 利用词嵌入矩阵将输入的数据中的词转换成词向量，维度[batch_size, sequence_length, embedding_size]
            self.embeddedWords = tf.nn.embedding_lookup(self.W, self.inputX)
            
        # 定义两层双向LSTM的模型结构
        with tf.name_scope("Bi-LSTM"):
            for idx, hiddenSize in enumerate(config.model.hiddenSizes):
                with tf.name_scope("Bi-LSTM" + str(idx)):
                    # 定义前向LSTM结构
                    lstmFwCell = tf.nn.rnn_cell.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(num_units=hiddenSize, state_is_tuple=True),
                                                                 output_keep_prob=self.dropoutKeepProb)
                    # 定义反向LSTM结构
                    lstmBwCell = tf.nn.rnn_cell.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(num_units=hiddenSize, state_is_tuple=True),
                                                                 output_keep_prob=self.dropoutKeepProb)


                    # 采用动态rnn，可以动态的输入序列的长度，若没有输入，则取序列的全长
                    # outputs是一个元祖(output_fw, output_bw)，其中两个元素的维度都是[batch_size, max_time, hidden_size],fw和bw的hidden_size一样
                    # self.current_state 是最终的状态，二元组(state_fw, state_bw)，state_fw=[batch_size, s]，s是一个元祖(h, c)
                    outputs_, self.current_state = tf.nn.bidirectional_dynamic_rnn(lstmFwCell, lstmBwCell, 
                                                                                  self.embeddedWords, dtype=tf.float32,
                                                                                  scope="bi-lstm" + str(idx))
        
                    # 对outputs中的fw和bw的结果拼接 [batch_size, time_step, hidden_size * 2], 传入到下一层Bi-LSTM中
                    self.embeddedWords = tf.concat(outputs_, 2)
                
        # 将最后一层Bi-LSTM输出的结果分割成前向和后向的输出
        outputs = tf.split(self.embeddedWords, 2, -1)
        
        # 在Bi-LSTM+Attention的论文中，将前向和后向的输出相加
        with tf.name_scope("Attention"):
            H = outputs[0] + outputs[1]

            # 得到Attention的输出
            output = self.attention(H)
            outputSize = config.model.hiddenSizes[-1]
        
        # 全连接层的输出
        with tf.name_scope("output"):
            outputW = tf.get_variable(
                "outputW",
                shape=[outputSize, 1],
                initializer=tf.contrib.layers.xavier_initializer())
            
            outputB= tf.Variable(tf.constant(0.1, shape=[1]), name="outputB")
            l2Loss += tf.nn.l2_loss(outputW)
            l2Loss += tf.nn.l2_loss(outputB)
            self.predictions = tf.nn.xw_plus_b(output, outputW, outputB, name="predictions")
            self.binaryPreds = tf.cast(tf.greater_equal(self.predictions, 0.5), tf.float32, name="binaryPreds")
        
        # 计算二元交叉熵损失
        with tf.name_scope("loss"):
            
            losses = tf.nn.sigmoid_cross_entropy_with_logits(logits=self.predictions, labels=self.inputY)
            self.loss = tf.reduce_mean(losses) + config.model.l2RegLambda * l2Loss
    
    def attention(self, H):
        """
        利用Attention机制得到句子的向量表示
        """
        # 获得最后一层LSTM的神经元数量
        hiddenSize = config.model.hiddenSizes[-1]
        
        # 初始化一个权重向量，是可训练的参数
        W = tf.Variable(tf.random_normal([hiddenSize], stddev=0.1))
        
        # 对Bi-LSTM的输出用激活函数做非线性转换
        M = tf.tanh(H)
        
        # 对W和M做矩阵运算，W=[batch_size, time_step, hidden_size]，计算前做维度转换成[batch_size * time_step, hidden_size]
        # newM = [batch_size, time_step, 1]，每一个时间步的输出由向量转换成一个数字
        newM = tf.matmul(tf.reshape(M, [-1, hiddenSize]), tf.reshape(W, [-1, 1]))
        
        # 对newM做维度转换成[batch_size, time_step]
        restoreM = tf.reshape(newM, [-1, config.sequenceLength])
        
        # 用softmax做归一化处理[batch_size, time_step]
        self.alpha = tf.nn.softmax(restoreM)
        
        # 利用求得的alpha的值对H进行加权求和，用矩阵运算直接操作
        r = tf.matmul(tf.transpose(H, [0, 2, 1]), tf.reshape(self.alpha, [-1, config.sequenceLength, 1]))
        
        # 将三维压缩成二维sequeezeR=[batch_size, hidden_size]
        sequeezeR = tf.squeeze(r)
        
        sentenceRepren = tf.tanh(sequeezeR)
        
        # 对Attention的输出可以做dropout处理
        output = tf.nn.dropout(sentenceRepren, self.dropoutKeepProb)
        
        return output

# %%
# 定义性能指标函数

def mean(item):
    return sum(item) / len(item)


def genMetrics(trueY, predY, binaryPredY):
    """
    生成acc和auc值
    """
    auc = roc_auc_score(trueY, predY)
    accuracy = accuracy_score(trueY, binaryPredY)
    precision = precision_score(trueY, binaryPredY)
    recall = recall_score(trueY, binaryPredY)
    
    return round(accuracy, 4), round(auc, 4), round(precision, 4), round(recall, 4)

# %%
# 训练模型

# 生成训练集和验证集
trainReviews = data.trainReviews
trainLabels = data.trainLabels
evalReviews = data.evalReviews
evalLabels = data.evalLabels

wordEmbedding = data.wordEmbedding

# 定义计算图
with tf.Graph().as_default():

    session_conf = tf.ConfigProto(allow_soft_placement=True, log_device_placement=False)
    session_conf.gpu_options.allow_growth=True
    session_conf.gpu_options.per_process_gpu_memory_fraction = 0.9  # 配置gpu占用率  

    sess = tf.Session(config=session_conf)
    
    # 定义会话
    with sess.as_default():
        lstm = BiLSTMAttention(config, wordEmbedding)
        
        globalStep = tf.Variable(0, name="globalStep", trainable=False)
        # 定义优化函数，传入学习速率参数
        optimizer = tf.train.AdamOptimizer(config.training.learningRate)
        # 计算梯度,得到梯度和变量
        gradsAndVars = optimizer.compute_gradients(lstm.loss)
        # 将梯度应用到变量下，生成训练器
        trainOp = optimizer.apply_gradients(gradsAndVars, global_step=globalStep)
        
        # 用summary绘制tensorBoard
        gradSummaries = []
        for g, v in gradsAndVars:
            if g is not None:
                tf.summary.histogram("{}/grad/hist".format(v.name), g)
                tf.summary.scalar("{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
        
        outDir = os.path.abspath(os.path.join(os.path.curdir, "summarys"))
        print("Writing to {}\n".format(outDir))
        
        lossSummary = tf.summary.scalar("loss", lstm.loss)
        summaryOp = tf.summary.merge_all()
        
        trainSummaryDir = os.path.join(outDir, "train")
        trainSummaryWriter = tf.summary.FileWriter(trainSummaryDir, sess.graph)
        
        evalSummaryDir = os.path.join(outDir, "eval")
        evalSummaryWriter = tf.summary.FileWriter(evalSummaryDir, sess.graph)
        
        
        # 初始化所有变量
#         saver = tf.train.Saver(tf.global_variables(), max_to_keep=5)
        
        # 保存模型的一种方式，保存为pb文件
#         builder = tf.saved_model.builder.SavedModelBuilder("../model/Bi-LSTM/savedModel")
        sess.run(tf.global_variables_initializer())

        def trainStep(batchX, batchY):
            """
            训练函数
            """   
            feed_dict = {
              lstm.inputX: batchX,
              lstm.inputY: batchY,
              lstm.dropoutKeepProb: config.model.dropoutKeepProb
            }
            _, summary, step, loss, predictions, binaryPreds = sess.run(
                [trainOp, summaryOp, globalStep, lstm.loss, lstm.predictions, lstm.binaryPreds],
                feed_dict)
            timeStr = datetime.datetime.now().isoformat()
            acc, auc, precision, recall = genMetrics(batchY, predictions, binaryPreds)
            print("{}, step: {}, loss: {}, acc: {}, auc: {}, precision: {}, recall: {}".format(timeStr, step, loss, acc, auc, precision, recall))
            trainSummaryWriter.add_summary(summary, step)

        def devStep(batchX, batchY):
            """
            验证函数
            """
            feed_dict = {
              lstm.inputX: batchX,
              lstm.inputY: batchY,
              lstm.dropoutKeepProb: 1.0
            }
            summary, step, loss, predictions, binaryPreds = sess.run(
                [summaryOp, globalStep, lstm.loss, lstm.predictions, lstm.binaryPreds],
                feed_dict)
            
            acc, auc, precision, recall = genMetrics(batchY, predictions, binaryPreds)
            
            evalSummaryWriter.add_summary(summary, step)
            
            return loss, acc, auc, precision, recall
        
        for i in range(config.training.epoches):
            # 训练模型
            print("start training model")
            for batchTrain in nextBatch(trainReviews, trainLabels, config.batchSize):
                trainStep(batchTrain[0], batchTrain[1])

                currentStep = tf.train.global_step(sess, globalStep) 
                if currentStep % config.training.evaluateEvery == 0:
                    print("\nEvaluation:")
                    
                    losses = []
                    accs = []
                    aucs = []
                    precisions = []
                    recalls = []
                    
                    for batchEval in nextBatch(evalReviews, evalLabels, config.batchSize):
                        loss, acc, auc, precision, recall = devStep(batchEval[0], batchEval[1])
                        losses.append(loss)
                        accs.append(acc)
                        aucs.append(auc)
                        precisions.append(precision)
                        recalls.append(recall)
                        
                    time_str = datetime.datetime.now().isoformat()
                    print("{}, step: {}, loss: {}, acc: {}, auc: {}, precision: {}, recall: {}".format(time_str, currentStep, mean(losses), 
                                                                                                       mean(accs), mean(aucs), mean(precisions),
                                                                                                       mean(recalls)))
                    
#                 if currentStep % config.training.checkpointEvery == 0:
#                     # 保存模型的另一种方法，保存checkpoint文件
#                     path = saver.save(sess, "../model/Bi-LSTM/model/my-model", global_step=currentStep)
#                     print("Saved model checkpoint to {}\n".format(path))
                    
#         inputs = {"inputX": tf.saved_model.utils.build_tensor_info(lstm.inputX),
#                   "keepProb": tf.saved_model.utils.build_tensor_info(lstm.dropoutKeepProb)}

#         outputs = {"binaryPreds": tf.saved_model.utils.build_tensor_info(lstm.binaryPreds)}

#         prediction_signature = tf.saved_model.signature_def_utils.build_signature_def(inputs=inputs, outputs=outputs,
#                                                                                       method_name=tf.saved_model.signature_constants.PREDICT_METHOD_NAME)
#         legacy_init_op = tf.group(tf.tables_initializer(), name="legacy_init_op")
#         builder.add_meta_graph_and_variables(sess, [tf.saved_model.tag_constants.SERVING],
#                                             signature_def_map={"predict": prediction_signature}, legacy_init_op=legacy_init_op)

#         builder.save()
# Out:
# INFO:tensorflow:Summary name embedding/W:0/grad/hist is illegal; using embedding/W_0/grad/hist instead.
# INFO:tensorflow:Summary name embedding/W:0/grad/sparsity is illegal; using embedding/W_0/grad/sparsity instead.
# INFO:tensorflow:Summary name bi-lstm0/fw/lstm_cell/kernel:0/grad/hist is illegal; using bi-lstm0/fw/lstm_cell/kernel_0/grad/hist instead.
# INFO:tensorflow:Summary name bi-lstm0/fw/lstm_cell/kernel:0/grad/sparsity is illegal; using bi-lstm0/fw/lstm_cell/kernel_0/grad/sparsity instead.
# INFO:tensorflow:Summary name bi-lstm0/fw/lstm_cell/bias:0/grad/hist is illegal; using bi-lstm0/fw/lstm_cell/bias_0/grad/hist instead.
# INFO:tensorflow:Summary name bi-lstm0/fw/lstm_cell/bias:0/grad/sparsity is illegal; using bi-lstm0/fw/lstm_cell/bias_0/grad/sparsity instead.
# INFO:tensorflow:Summary name bi-lstm0/bw/lstm_cell/kernel:0/grad/hist is illegal; using bi-lstm0/bw/lstm_cell/kernel_0/grad/hist instead.
# INFO:tensorflow:Summary name bi-lstm0/bw/lstm_cell/kernel:0/grad/sparsity is illegal; using bi-lstm0/bw/lstm_cell/kernel_0/grad/sparsity instead.
# INFO:tensorflow:Summary name bi-lstm0/bw/lstm_cell/bias:0/grad/hist is illegal; using bi-lstm0/bw/lstm_cell/bias_0/grad/hist instead.
# INFO:tensorflow:Summary name bi-lstm0/bw/lstm_cell/bias:0/grad/sparsity is illegal; using bi-lstm0/bw/lstm_cell/bias_0/grad/sparsity instead.
# INFO:tensorflow:Summary name bi-lstm1/fw/lstm_cell/kernel:0/grad/hist is illegal; using bi-lstm1/fw/lstm_cell/kernel_0/grad/hist instead.
# INFO:tensorflow:Summary name bi-lstm1/fw/lstm_cell/kernel:0/grad/sparsity is illegal; using bi-lstm1/fw/lstm_cell/kernel_0/grad/sparsity instead.
# INFO:tensorflow:Summary name bi-lstm1/fw/lstm_cell/bias:0/grad/hist is illegal; using bi-lstm1/fw/lstm_cell/bias_0/grad/hist instead.
# INFO:tensorflow:Summary name bi-lstm1/fw/lstm_cell/bias:0/grad/sparsity is illegal; using bi-lstm1/fw/lstm_cell/bias_0/grad/sparsity instead.
# INFO:tensorflow:Summary name bi-lstm1/bw/lstm_cell/kernel:0/grad/hist is illegal; using bi-lstm1/bw/lstm_cell/kernel_0/grad/hist instead.
# INFO:tensorflow:Summary name bi-lstm1/bw/lstm_cell/kernel:0/grad/sparsity is illegal; using bi-lstm1/bw/lstm_cell/kernel_0/grad/sparsity instead.
# INFO:tensorflow:Summary name bi-lstm1/bw/lstm_cell/bias:0/grad/hist is illegal; using bi-lstm1/bw/lstm_cell/bias_0/grad/hist instead.
# INFO:tensorflow:Summary name bi-lstm1/bw/lstm_cell/bias:0/grad/sparsity is illegal; using bi-lstm1/bw/lstm_cell/bias_0/grad/sparsity instead.
# INFO:tensorflow:Summary name Attention/Variable:0/grad/hist is illegal; using Attention/Variable_0/grad/hist instead.
# INFO:tensorflow:Summary name Attention/Variable:0/grad/sparsity is illegal; using Attention/Variable_0/grad/sparsity instead.
# INFO:tensorflow:Summary name outputW:0/grad/hist is illegal; using outputW_0/grad/hist instead.
# INFO:tensorflow:Summary name outputW:0/grad/sparsity is illegal; using outputW_0/grad/sparsity instead.
# INFO:tensorflow:Summary name output/outputB:0/grad/hist is illegal; using output/outputB_0/grad/hist instead.
# INFO:tensorflow:Summary name output/outputB:0/grad/sparsity is illegal; using output/outputB_0/grad/sparsity instead.
# Writing to E:\pythonWp\nlp\textClassifier\Bi-LSTM+Attention\summarys
#
# start training model
# 2019-03-18T10:27:01.185934, step: 1, loss: 0.6941850185394287, acc: 0.5078, auc: 0.5306, precision: 0.0, recall: 0.0
# 2019-03-18T10:27:06.807451, step: 2, loss: 0.6824713945388794, acc: 0.5156, auc: 0.629, precision: 0.0, recall: 0.0
# 2019-03-18T10:27:12.542183, step: 3, loss: 0.6646747589111328, acc: 0.5234, auc: 0.7181, precision: 0.0, recall: 0.0
# 2019-03-18T10:27:18.375537, step: 4, loss: 0.6439853310585022, acc: 0.5469, auc: 0.7639, precision: 1.0, recall: 0.1212
# 2019-03-18T10:27:24.523211, step: 5, loss: 0.616479754447937, acc: 0.5625, auc: 0.7746, precision: 1.0, recall: 0.1385
# 2019-03-18T10:27:30.988323, step: 6, loss: 0.5785282850265503, acc: 0.7031, auc: 0.7766, precision: 0.7424, recall: 0.7
# 2019-03-18T10:27:37.130472, step: 7, loss: 1.276415228843689, acc: 0.5312, auc: 0.7438, precision: 1.0, recall: 0.1045
# 2019-03-18T10:27:43.387786, step: 8, loss: 0.452808141708374, acc: 0.8047, auc: 0.8916, precision: 0.9524, recall: 0.6349
# 2019-03-18T10:27:49.894335, step: 9, loss: 0.8104026317596436, acc: 0.625, auc: 0.8016, precision: 0.5596, recall: 1.0
# 2019-03-18T10:27:56.245136, step: 10, loss: 0.7220087051391602, acc: 0.6562, auc: 0.8048, precision: 0.5543, recall: 0.9444
# 2019-03-18T10:28:02.513547, step: 11, loss: 0.6092270612716675, acc: 0.7969, auc: 0.8483, precision: 0.7931, recall: 0.7667
# 2019-03-18T10:28:08.963663, step: 12, loss: 0.5842453241348267, acc: 0.6406, auc: 0.8791, precision: 0.8261, recall: 0.3115
# 2019-03-18T10:28:15.093950, step: 13, loss: 0.6187528371810913, acc: 0.4766, auc: 0.8426, precision: 1.0, recall: 0.0429
# 2019-03-18T10:28:21.306582, step: 14, loss: 0.6202520132064819, acc: 0.5156, auc: 0.8226, precision: 0.0, recall: 0.0
# 2019-03-18T10:28:27.861389, step: 15, loss: 0.6253339052200317, acc: 0.5391, auc: 0.7838, precision: 1.0, recall: 0.0167
# 2019-03-18T10:28:34.770728, step: 16, loss: 0.6236758828163147, acc: 0.5156, auc: 0.827, precision: 0.0, recall: 0.0
# 2019-03-18T10:28:42.655616, step: 17, loss: 0.6364296078681946, acc: 0.5078, auc: 0.801, precision: 0.0, recall: 0.0
# 2019-03-18T10:28:51.241148, step: 18, loss: 0.6434653997421265, acc: 0.5, auc: 0.8225, precision: 0.0, recall: 0.0
# 2019-03-18T10:28:59.394820, step: 19, loss: 0.606102466583252, acc: 0.5938, auc: 0.8035, precision: 1.0, recall: 0.0189
# 2019-03-18T10:29:07.251221, step: 20, loss: 0.6105097532272339, acc: 0.5312, auc: 0.8342, precision: 1.0, recall: 0.0625
# 2019-03-18T10:29:14.986037, step: 21, loss: 0.6063239574432373, acc: 0.5156, auc: 0.8135, precision: 1.0, recall: 0.0606
# 2019-03-18T10:29:23.102679, step: 22, loss: 0.5991557836532593, acc: 0.625, auc: 0.8364, precision: 0.9231, recall: 0.2034
# 2019-03-18T10:29:30.826943, step: 23, loss: 0.5957363247871399, acc: 0.6016, auc: 0.8327, precision: 0.95, recall: 0.2754
# 2019-03-18T10:29:37.975048, step: 24, loss: 0.5834392309188843, acc: 0.6875, auc: 0.8419, precision: 0.8684, recall: 0.4853
# 2019-03-18T10:29:45.287063, step: 25, loss: 0.5639288425445557, acc: 0.7266, auc: 0.8256, precision: 0.9118, recall: 0.4921
# 2019-03-18T10:29:53.072796, step: 26, loss: 0.5151585340499878, acc: 0.75, auc: 0.8885, precision: 0.8913, recall: 0.6029
# 2019-03-18T10:30:00.368859, step: 27, loss: 0.4814847707748413, acc: 0.8125, auc: 0.8884, precision: 0.8704, recall: 0.7344
# 2019-03-18T10:30:08.038725, step: 28, loss: 0.5067920684814453, acc: 0.7266, auc: 0.8443, precision: 0.8679, recall: 0.6216
# 2019-03-18T10:30:15.537728, step: 29, loss: 0.3080774247646332, acc: 0.8594, auc: 0.9466, precision: 0.875, recall: 0.8167
# 2019-03-18T10:30:23.565443, step: 30, loss: 0.5167075395584106, acc: 0.7812, auc: 0.8594, precision: 0.8615, recall: 0.7467
# 2019-03-18T10:30:31.559996, step: 31, loss: 0.6693805456161499, acc: 0.7188, auc: 0.8427, precision: 0.6593, recall: 0.9231
# 2019-03-18T10:30:40.072918, step: 32, loss: 0.5244184732437134, acc: 0.6953, auc: 0.8503, precision: 0.6622, recall: 0.7778
# 2019-03-18T10:30:48.603763, step: 33, loss: 0.4317864179611206, acc: 0.7656, auc: 0.868, precision: 0.8116, recall: 0.7671
# 2019-03-18T10:30:57.704556, step: 34, loss: 0.4216799736022949, acc: 0.8125, auc: 0.9007, precision: 0.9302, recall: 0.6557
# 2019-03-18T10:31:07.150922, step: 35, loss: 0.4825896620750427, acc: 0.6797, auc: 0.8625, precision: 0.8276, recall: 0.4
# 2019-03-18T10:31:15.643833, step: 36, loss: 0.4676322638988495, acc: 0.7109, auc: 0.885, precision: 0.871, recall: 0.45
# 2019-03-18T10:31:24.482177, step: 37, loss: 0.46686041355133057, acc: 0.7031, auc: 0.8793, precision: 0.8846, recall: 0.3966
# 2019-03-18T10:31:33.004764, step: 38, loss: 0.4432946741580963, acc: 0.7812, auc: 0.8954, precision: 0.9429, recall: 0.5593
# 2019-03-18T10:31:41.666579, step: 39, loss: 0.4793005585670471, acc: 0.7422, auc: 0.8568, precision: 0.8085, recall: 0.6129
# 2019-03-18T10:31:50.328176, step: 40, loss: 0.5487841963768005, acc: 0.7578, auc: 0.7954, precision: 0.8, recall: 0.7164
# 2019-03-18T10:31:58.407356, step: 41, loss: 0.447235107421875, acc: 0.7891, auc: 0.8892, precision: 0.803, recall: 0.791
# 2019-03-18T10:32:06.502061, step: 42, loss: 0.5179702043533325, acc: 0.7656, auc: 0.8324, precision: 0.7581, recall: 0.7581
# 2019-03-18T10:32:15.035090, step: 43, loss: 0.4230799078941345, acc: 0.8125, auc: 0.9042, precision: 0.8485, recall: 0.8
# 2019-03-18T10:32:22.578345, step: 44, loss: 0.44611892104148865, acc: 0.7656, auc: 0.878, precision: 0.8889, recall: 0.6667
# 2019-03-18T10:32:31.756723, step: 45, loss: 0.4243914783000946, acc: 0.7969, auc: 0.8902, precision: 0.8864, recall: 0.65
# 2019-03-18T10:32:40.238237, step: 46, loss: 0.33859604597091675, acc: 0.8281, auc: 0.9348, precision: 0.8596, recall: 0.7778
# 2019-03-18T10:32:48.246060, step: 47, loss: 0.33185142278671265, acc: 0.8125, auc: 0.9361, precision: 0.8302, recall: 0.7458
# 2019-03-18T10:32:55.702024, step: 48, loss: 0.29110267758369446, acc: 0.8906, auc: 0.9504, precision: 0.9403, recall: 0.863
# 2019-03-18T10:33:03.701251, step: 49, loss: 0.47441259026527405, acc: 0.7891, auc: 0.8812, precision: 0.7536, recall: 0.8387
# 2019-03-18T10:33:12.230809, step: 50, loss: 0.4076458513736725, acc: 0.8359, auc: 0.9082, precision: 0.8772, recall: 0.7812
# 2019-03-18T10:33:19.812270, step: 51, loss: 0.451723575592041, acc: 0.8047, auc: 0.9027, precision: 0.9592, recall: 0.6714
# 2019-03-18T10:33:28.065356, step: 52, loss: 0.3495035171508789, acc: 0.8594, auc: 0.9222, precision: 0.898, recall: 0.7719
# 2019-03-18T10:33:36.017964, step: 53, loss: 0.3288845419883728, acc: 0.8359, auc: 0.9357, precision: 0.8767, recall: 0.8421
# 2019-03-18T10:33:44.636733, step: 54, loss: 0.3204299211502075, acc: 0.8828, auc: 0.9603, precision: 0.8358, recall: 0.9333
# 2019-03-18T10:33:53.098581, step: 55, loss: 0.4074522852897644, acc: 0.8203, auc: 0.8937, precision: 0.8197, recall: 0.8065
# 2019-03-18T10:34:01.399020, step: 56, loss: 0.4109080731868744, acc: 0.7812, auc: 0.8919, precision: 0.8571, recall: 0.7059
# 2019-03-18T10:34:09.569730, step: 57, loss: 0.46937745809555054, acc: 0.7969, auc: 0.885, precision: 0.9524, recall: 0.625
# 2019-03-18T10:34:18.197868, step: 58, loss: 0.3099900782108307, acc: 0.8672, auc: 0.9456, precision: 0.9206, recall: 0.8286
# 2019-03-18T10:34:26.126925, step: 59, loss: 0.36395275592803955, acc: 0.8438, auc: 0.9172, precision: 0.8772, recall: 0.7937
# 2019-03-18T10:34:34.081717, step: 60, loss: 0.32947224378585815, acc: 0.9062, auc: 0.95, precision: 0.8714, recall: 0.9531
# 2019-03-18T10:34:42.229928, step: 61, loss: 0.3874007761478424, acc: 0.8516, auc: 0.9285, precision: 0.8261, recall: 0.8906
# 2019-03-18T10:34:50.375611, step: 62, loss: 0.3379598557949066, acc: 0.8906, auc: 0.941, precision: 0.8955, recall: 0.8955
# 2019-03-18T10:34:59.382140, step: 63, loss: 0.42931029200553894, acc: 0.8047, auc: 0.9068, precision: 0.9565, recall: 0.6567
# 2019-03-18T10:35:07.978072, step: 64, loss: 0.4221968352794647, acc: 0.7422, auc: 0.9099, precision: 0.8974, recall: 0.5469
# 2019-03-18T10:35:16.117874, step: 65, loss: 0.3512171506881714, acc: 0.8203, auc: 0.9227, precision: 0.88, recall: 0.7213
# 2019-03-18T10:35:24.409972, step: 66, loss: 0.2877717912197113, acc: 0.8672, auc: 0.9553, precision: 0.9091, recall: 0.8065
# 2019-03-18T10:35:32.803039, step: 67, loss: 0.35472407937049866, acc: 0.875, auc: 0.9309, precision: 0.8529, recall: 0.9062
# 2019-03-18T10:35:40.782514, step: 68, loss: 0.29958558082580566, acc: 0.8906, auc: 0.9489, precision: 0.8955, recall: 0.8955
# 2019-03-18T10:35:49.372455, step: 69, loss: 0.3483717143535614, acc: 0.8203, auc: 0.928, precision: 0.8475, recall: 0.7812
# 2019-03-18T10:35:57.619993, step: 70, loss: 0.29112040996551514, acc: 0.875, auc: 0.9498, precision: 0.9412, recall: 0.7869
# 2019-03-18T10:36:06.379375, step: 71, loss: 0.2916077971458435, acc: 0.8359, auc: 0.96, precision: 0.94, recall: 0.7231
# 2019-03-18T10:36:14.892967, step: 72, loss: 0.34297898411750793, acc: 0.8516, auc: 0.9298, precision: 0.9375, recall: 0.8
# 2019-03-18T10:36:23.134750, step: 73, loss: 0.38429123163223267, acc: 0.8516, auc: 0.9166, precision: 0.875, recall: 0.8358
# 2019-03-18T10:36:31.428443, step: 74, loss: 0.3584739565849304, acc: 0.875, auc: 0.9426, precision: 0.8235, recall: 0.9333
# 2019-03-18T10:36:40.329309, step: 75, loss: 0.25533539056777954, acc: 0.9141, auc: 0.9753, precision: 0.8793, recall: 0.9273
# 2019-03-18T10:36:48.702456, step: 76, loss: 0.3395369052886963, acc: 0.8281, auc: 0.9377, precision: 0.9545, recall: 0.6774
# 2019-03-18T10:36:57.287488, step: 77, loss: 0.31966206431388855, acc: 0.8516, auc: 0.9404, precision: 0.9216, recall: 0.7581
# 2019-03-18T10:37:05.739391, step: 78, loss: 0.29079318046569824, acc: 0.875, auc: 0.9545, precision: 0.963, recall: 0.7879
# 2019-03-18T10:37:14.942537, step: 79, loss: 0.27289262413978577, acc: 0.8672, auc: 0.9591, precision: 0.8909, recall: 0.8167
# 2019-03-18T10:37:24.414587, step: 80, loss: 0.30206429958343506, acc: 0.8672, auc: 0.9451, precision: 0.8732, recall: 0.8857
# 2019-03-18T10:37:33.006318, step: 81, loss: 0.31452080607414246, acc: 0.9062, auc: 0.9412, precision: 0.9041, recall: 0.9296
# 2019-03-18T10:37:41.463497, step: 82, loss: 0.44023627042770386, acc: 0.8281, auc: 0.8931, precision: 0.8286, recall: 0.8529
# 2019-03-18T10:37:50.699995, step: 83, loss: 0.29760122299194336, acc: 0.8438, auc: 0.9394, precision: 0.875, recall: 0.7903
# 2019-03-18T10:37:59.466332, step: 84, loss: 0.31516575813293457, acc: 0.8438, auc: 0.9592, precision: 0.9811, recall: 0.7324
# 2019-03-18T10:38:08.138501, step: 85, loss: 0.2543116509914398, acc: 0.875, auc: 0.9599, precision: 0.96, recall: 0.7742
# 2019-03-18T10:38:16.848392, step: 86, loss: 0.2948555648326874, acc: 0.8672, auc: 0.9495, precision: 0.9107, recall: 0.8095
# 2019-03-18T10:38:26.833670, step: 87, loss: 0.38221117854118347, acc: 0.8438, auc: 0.913, precision: 0.8421, recall: 0.8136
# 2019-03-18T10:38:35.549820, step: 88, loss: 0.2901792824268341, acc: 0.875, auc: 0.9547, precision: 0.8571, recall: 0.8235
# 2019-03-18T10:38:44.680307, step: 89, loss: 0.3506211042404175, acc: 0.8203, auc: 0.9268, precision: 0.8235, recall: 0.8358
# 2019-03-18T10:38:53.428290, step: 90, loss: 0.2735126316547394, acc: 0.8516, auc: 0.9648, precision: 0.9574, recall: 0.7258
# 2019-03-18T10:39:02.334937, step: 91, loss: 0.3098389208316803, acc: 0.875, auc: 0.9404, precision: 0.9219, recall: 0.8429
# 2019-03-18T10:39:11.085971, step: 92, loss: 0.42207634449005127, acc: 0.7891, auc: 0.8953, precision: 0.8033, recall: 0.7656
# 2019-03-18T10:39:19.570409, step: 93, loss: 0.3233070969581604, acc: 0.8516, auc: 0.9355, precision: 0.8596, recall: 0.8167
# 2019-03-18T10:39:27.749715, step: 94, loss: 0.295979380607605, acc: 0.8672, auc: 0.948, precision: 0.8833, recall: 0.8413
# 2019-03-18T10:39:36.857446, step: 95, loss: 0.28144508600234985, acc: 0.8594, auc: 0.9548, precision: 0.8852, recall: 0.8308
# 2019-03-18T10:39:45.390328, step: 96, loss: 0.23235292732715607, acc: 0.8516, auc: 0.9772, precision: 0.9362, recall: 0.7333
# 2019-03-18T10:39:54.103151, step: 97, loss: 0.28125250339508057, acc: 0.8906, auc: 0.9507, precision: 0.9178, recall: 0.8933
# 2019-03-18T10:40:02.519762, step: 98, loss: 0.302450567483902, acc: 0.8906, auc: 0.9443, precision: 0.9167, recall: 0.8594
# 2019-03-18T10:40:11.311242, step: 99, loss: 0.3369276821613312, acc: 0.8438, auc: 0.9309, precision: 0.8689, recall: 0.8154
# 2019-03-18T10:40:20.240084, step: 100, loss: 0.3540538549423218, acc: 0.875, auc: 0.9384, precision: 0.8286, recall: 0.9355
#
# Evaluation:
# 2019-03-18T10:45:59.195327, step: 100, loss: 0.31401199560899, acc: 0.8627820512820512, auc: 0.9410538461538462, precision: 0.8895128205128205, recall: 0.832828205128205
# 2019-03-18T10:46:08.066317, step: 101, loss: 0.3664247989654541, acc: 0.8281, auc: 0.9168, precision: 0.8305, recall: 0.8033
# 2019-03-18T10:46:17.324922, step: 102, loss: 0.2976197600364685, acc: 0.8594, auc: 0.9521, precision: 0.9636, recall: 0.7681
# 2019-03-18T10:46:27.522749, step: 103, loss: 0.44489216804504395, acc: 0.8281, auc: 0.9029, precision: 0.8197, recall: 0.8197
# 2019-03-18T10:46:38.230457, step: 104, loss: 0.3469655215740204, acc: 0.8516, auc: 0.9272, precision: 0.9016, recall: 0.8088
# 2019-03-18T10:46:47.137124, step: 105, loss: 0.31170859932899475, acc: 0.8594, auc: 0.9362, precision: 0.8776, recall: 0.7818
# 2019-03-18T10:46:57.231434, step: 106, loss: 0.28250652551651, acc: 0.8594, auc: 0.9536, precision: 0.8929, recall: 0.8065
# 2019-03-18T10:47:07.585390, step: 107, loss: 0.39613276720046997, acc: 0.8516, auc: 0.9, precision: 0.8571, recall: 0.8696
# 2019-03-18T10:47:19.004482, step: 108, loss: 0.28726932406425476, acc: 0.8984, auc: 0.9586, precision: 0.8814, recall: 0.8966
# 2019-03-18T10:47:29.061152, step: 109, loss: 0.2769928574562073, acc: 0.8984, auc: 0.9558, precision: 0.9492, recall: 0.8485
# 2019-03-18T10:47:38.535152, step: 110, loss: 0.33353573083877563, acc: 0.8438, auc: 0.9299, precision: 0.8772, recall: 0.7937
# 2019-03-18T10:47:48.678463, step: 111, loss: 0.2757161855697632, acc: 0.8828, auc: 0.9587, precision: 0.8983, recall: 0.8548
# 2019-03-18T10:47:58.512624, step: 112, loss: 0.48012638092041016, acc: 0.7734, auc: 0.8742, precision: 0.9167, recall: 0.6377
# 2019-03-18T10:48:08.209312, step: 113, loss: 0.42112278938293457, acc: 0.7891, auc: 0.8914, precision: 0.8478, recall: 0.661
# 2019-03-18T10:48:18.367769, step: 114, loss: 0.311423122882843, acc: 0.8672, auc: 0.9414, precision: 0.8966, recall: 0.8254
# 2019-03-18T10:48:27.853957, step: 115, loss: 0.25307148694992065, acc: 0.8906, auc: 0.9682, precision: 0.9516, recall: 0.8429
# 2019-03-18T10:48:37.388455, step: 116, loss: 0.3365996778011322, acc: 0.8516, auc: 0.9374, precision: 0.8571, recall: 0.8696
# 2019-03-18T10:48:46.705086, step: 117, loss: 0.33247822523117065, acc: 0.875, auc: 0.9361, precision: 0.8571, recall: 0.8852
# 2019-03-18T10:48:56.730511, step: 118, loss: 0.2982661724090576, acc: 0.875, auc: 0.9456, precision: 0.9, recall: 0.8438
# 2019-03-18T10:49:06.177803, step: 119, loss: 0.2855149805545807, acc: 0.875, auc: 0.9529, precision: 0.9444, recall: 0.7969
# 2019-03-18T10:49:15.547293, step: 120, loss: 0.2901451289653778, acc: 0.8828, auc: 0.9537, precision: 0.9677, recall: 0.8219
# 2019-03-18T10:49:24.799161, step: 121, loss: 0.23058465123176575, acc: 0.8906, auc: 0.9708, precision: 0.9091, recall: 0.8475
# 2019-03-18T10:49:34.518789, step: 122, loss: 0.28818580508232117, acc: 0.8984, auc: 0.956, precision: 0.9828, recall: 0.8261
# 2019-03-18T10:49:43.838166, step: 123, loss: 0.3831726014614105, acc: 0.8516, auc: 0.9167, precision: 0.8382, recall: 0.8769
# 2019-03-18T10:49:55.972142, step: 124, loss: 0.3112970292568207, acc: 0.9219, auc: 0.9404, precision: 0.9231, recall: 0.9231
# 2019-03-18T10:50:08.259696, step: 125, loss: 0.29549750685691833, acc: 0.8906, auc: 0.9451, precision: 0.9, recall: 0.9
# 2019-03-18T10:50:18.318186, step: 126, loss: 0.22972331941127777, acc: 0.8984, auc: 0.9727, precision: 0.8679, recall: 0.8846
# 2019-03-18T10:50:27.683368, step: 127, loss: 0.5672157406806946, acc: 0.7578, auc: 0.8884, precision: 0.925, recall: 0.5692
# 2019-03-18T10:50:37.371421, step: 128, loss: 0.26884597539901733, acc: 0.8516, auc: 0.9557, precision: 0.9138, recall: 0.791
# 2019-03-18T10:50:46.959984, step: 129, loss: 0.29585859179496765, acc: 0.8828, auc: 0.95, precision: 0.8689, recall: 0.8833
# 2019-03-18T10:50:56.055554, step: 130, loss: 0.3058546781539917, acc: 0.875, auc: 0.9436, precision: 0.873, recall: 0.873
# 2019-03-18T10:51:05.275188, step: 131, loss: 0.3040730953216553, acc: 0.8906, auc: 0.9549, precision: 0.8966, recall: 0.8667
# 2019-03-18T10:51:14.922173, step: 132, loss: 0.307025283575058, acc: 0.875, auc: 0.9433, precision: 0.8852, recall: 0.8571
# 2019-03-18T10:51:24.209609, step: 133, loss: 0.2877858281135559, acc: 0.8906, auc: 0.9485, precision: 0.9298, recall: 0.8413
# 2019-03-18T10:51:33.661425, step: 134, loss: 0.29694420099258423, acc: 0.8203, auc: 0.9458, precision: 0.9123, recall: 0.7429
# 2019-03-18T10:51:43.141194, step: 135, loss: 0.3133252263069153, acc: 0.8281, auc: 0.946, precision: 0.8627, recall: 0.7458
# 2019-03-18T10:51:53.205708, step: 136, loss: 0.28746724128723145, acc: 0.8672, auc: 0.9486, precision: 0.9231, recall: 0.7869
# 2019-03-18T10:52:02.760624, step: 137, loss: 0.35644036531448364, acc: 0.8672, auc: 0.933, precision: 0.8438, recall: 0.8852
# 2019-03-18T10:52:11.880786, step: 138, loss: 0.29274776577949524, acc: 0.875, auc: 0.9524, precision: 0.913, recall: 0.863
# 2019-03-18T10:52:22.233580, step: 139, loss: 0.23370447754859924, acc: 0.9219, auc: 0.9672, precision: 0.9385, recall: 0.9104
# 2019-03-18T10:52:31.426336, step: 140, loss: 0.3001668453216553, acc: 0.8516, auc: 0.9462, precision: 0.8627, recall: 0.7857
# 2019-03-18T10:52:40.115398, step: 141, loss: 0.24886563420295715, acc: 0.8516, auc: 0.9658, precision: 0.9111, recall: 0.7321
# 2019-03-18T10:52:49.357179, step: 142, loss: 0.2535717487335205, acc: 0.8906, auc: 0.9608, precision: 0.92, recall: 0.8214
# 2019-03-18T10:52:58.391801, step: 143, loss: 0.35930633544921875, acc: 0.8438, auc: 0.9359, precision: 0.9362, recall: 0.7213
# 2019-03-18T10:53:07.835782, step: 144, loss: 0.262051522731781, acc: 0.8828, auc: 0.9589, precision: 0.8909, recall: 0.8448
# 2019-03-18T10:53:16.873046, step: 145, loss: 0.2918955981731415, acc: 0.8672, auc: 0.9446, precision: 0.9155, recall: 0.8553
# 2019-03-18T10:53:25.823079, step: 146, loss: 0.26512885093688965, acc: 0.9219, auc: 0.9658, precision: 0.8841, recall: 0.9683
# 2019-03-18T10:53:35.154788, step: 147, loss: 0.2263583242893219, acc: 0.9141, auc: 0.9789, precision: 0.8621, recall: 0.9434
# 2019-03-18T10:53:43.986916, step: 148, loss: 0.2798164486885071, acc: 0.9141, auc: 0.9585, precision: 0.8966, recall: 0.9123
# 2019-03-18T10:53:52.932615, step: 149, loss: 0.3980115056037903, acc: 0.8125, auc: 0.9268, precision: 0.9474, recall: 0.6207
# 2019-03-18T10:54:01.978809, step: 150, loss: 0.5023560523986816, acc: 0.7656, auc: 0.8952, precision: 0.8636, recall: 0.6129
# 2019-03-18T10:54:10.989250, step: 151, loss: 0.2952159643173218, acc: 0.8672, auc: 0.9699, precision: 0.9655, recall: 0.7887
# 2019-03-18T10:54:20.073729, step: 152, loss: 0.23314176499843597, acc: 0.9062, auc: 0.9687, precision: 0.918, recall: 0.8889
# 2019-03-18T10:54:28.891885, step: 153, loss: 0.3023465871810913, acc: 0.8906, auc: 0.9555, precision: 0.8636, recall: 0.9194
# 2019-03-18T10:54:37.537164, step: 154, loss: 0.27077579498291016, acc: 0.9219, auc: 0.9768, precision: 0.8841, recall: 0.9683
# 2019-03-18T10:54:47.070339, step: 155, loss: 0.3686964213848114, acc: 0.8438, auc: 0.9208, precision: 0.8382, recall: 0.8636
# 2019-03-18T10:54:55.830017, step: 156, loss: 0.27895551919937134, acc: 0.875, auc: 0.9634, precision: 0.8772, recall: 0.8475
# start training model
# 2019-03-18T10:55:05.043501, step: 157, loss: 0.2865213453769684, acc: 0.8516, auc: 0.9639, precision: 0.9583, recall: 0.7302
# 2019-03-18T10:55:14.238048, step: 158, loss: 0.38916850090026855, acc: 0.8047, auc: 0.934, precision: 0.9744, recall: 0.6129
# 2019-03-18T10:55:23.658425, step: 159, loss: 0.23751777410507202, acc: 0.8516, auc: 0.9814, precision: 1.0, recall: 0.6415
# 2019-03-18T10:55:32.682202, step: 160, loss: 0.24595379829406738, acc: 0.8984, auc: 0.9625, precision: 0.9348, recall: 0.8113
# 2019-03-18T10:55:41.241303, step: 161, loss: 0.2964124083518982, acc: 0.8516, auc: 0.9464, precision: 0.8939, recall: 0.831
# 2019-03-18T10:55:50.450955, step: 162, loss: 0.2586987614631653, acc: 0.8984, auc: 0.9697, precision: 0.8772, recall: 0.8929
# 2019-03-18T10:56:00.057932, step: 163, loss: 0.215352863073349, acc: 0.9141, auc: 0.98, precision: 0.9077, recall: 0.9219
# 2019-03-18T10:56:08.877363, step: 164, loss: 0.17400702834129333, acc: 0.9609, auc: 0.9934, precision: 0.9836, recall: 0.9375
# 2019-03-18T10:56:18.191177, step: 165, loss: 0.20148350298404694, acc: 0.9219, auc: 0.9788, precision: 0.9245, recall: 0.8909
# 2019-03-18T10:56:27.302128, step: 166, loss: 0.21072041988372803, acc: 0.8984, auc: 0.9693, precision: 0.8833, recall: 0.8983
# 2019-03-18T10:56:36.790052, step: 167, loss: 0.27663102746009827, acc: 0.8672, auc: 0.9565, precision: 0.9375, recall: 0.7627
# 2019-03-18T10:56:46.017949, step: 168, loss: 0.2383214384317398, acc: 0.9141, auc: 0.9719, precision: 0.9828, recall: 0.8507
# 2019-03-18T10:56:54.889046, step: 169, loss: 0.263083279132843, acc: 0.9219, auc: 0.9544, precision: 0.931, recall: 0.9
# 2019-03-18T10:57:04.500406, step: 170, loss: 0.22753234207630157, acc: 0.8828, auc: 0.9717, precision: 0.9444, recall: 0.8095
# 2019-03-18T10:57:13.528286, step: 171, loss: 0.1882070004940033, acc: 0.9297, auc: 0.9861, precision: 0.9219, recall: 0.9365
# 2019-03-18T10:57:22.447822, step: 172, loss: 0.22431766986846924, acc: 0.9375, auc: 0.9813, precision: 0.8923, recall: 0.9831
# 2019-03-18T10:57:31.433434, step: 173, loss: 0.1342667043209076, acc: 0.9531, auc: 0.9914, precision: 1.0, recall: 0.913
# 2019-03-18T10:57:40.612847, step: 174, loss: 0.21732580661773682, acc: 0.8906, auc: 0.9726, precision: 0.9385, recall: 0.8592
# 2019-03-18T10:57:49.550097, step: 175, loss: 0.19443362951278687, acc: 0.8984, auc: 0.9807, precision: 0.931, recall: 0.8571
# 2019-03-18T10:57:58.643249, step: 176, loss: 0.21213006973266602, acc: 0.8828, auc: 0.9725, precision: 0.9219, recall: 0.8551
# 2019-03-18T10:58:07.076521, step: 177, loss: 0.23302946984767914, acc: 0.8984, auc: 0.9741, precision: 0.9492, recall: 0.8485
# 2019-03-18T10:58:16.369095, step: 178, loss: 0.3349497318267822, acc: 0.8828, auc: 0.9397, precision: 0.8889, recall: 0.875
# 2019-03-18T10:58:25.213968, step: 179, loss: 0.21833807229995728, acc: 0.9141, auc: 0.9796, precision: 0.8519, recall: 0.9388
# 2019-03-18T10:58:34.060719, step: 180, loss: 0.17783239483833313, acc: 0.9297, auc: 0.981, precision: 0.9552, recall: 0.9143
# 2019-03-18T10:58:42.999974, step: 181, loss: 0.21955403685569763, acc: 0.8828, auc: 0.9744, precision: 0.9464, recall: 0.8154
# 2019-03-18T10:58:52.238158, step: 182, loss: 0.1574845016002655, acc: 0.9453, auc: 0.9828, precision: 0.9811, recall: 0.8966
# 2019-03-18T10:59:01.393561, step: 183, loss: 0.1466762125492096, acc: 0.9531, auc: 0.9869, precision: 0.9706, recall: 0.9429
# 2019-03-18T10:59:10.419229, step: 184, loss: 0.16766038537025452, acc: 0.9062, auc: 0.9861, precision: 0.9194, recall: 0.8906
# 2019-03-18T10:59:19.392942, step: 185, loss: 0.42995235323905945, acc: 0.8516, auc: 0.9222, precision: 0.7679, recall: 0.8776
# 2019-03-18T10:59:28.550678, step: 186, loss: 0.23952490091323853, acc: 0.9297, auc: 0.9626, precision: 0.9531, recall: 0.9104
# 2019-03-18T10:59:37.188732, step: 187, loss: 0.31729856133461, acc: 0.9062, auc: 0.9363, precision: 0.9649, recall: 0.8462
# 2019-03-18T10:59:46.149444, step: 188, loss: 0.29481399059295654, acc: 0.8672, auc: 0.9624, precision: 0.9623, recall: 0.7727
# 2019-03-18T10:59:55.249086, step: 189, loss: 0.2526730000972748, acc: 0.8594, auc: 0.9607, precision: 0.918, recall: 0.8116
# 2019-03-18T11:00:04.375958, step: 190, loss: 0.18482764065265656, acc: 0.9531, auc: 0.9927, precision: 0.913, recall: 1.0
# 2019-03-18T11:00:13.339512, step: 191, loss: 0.23670843243598938, acc: 0.9062, auc: 0.9688, precision: 0.9062, recall: 0.9062
# 2019-03-18T11:00:22.124198, step: 192, loss: 0.22247916460037231, acc: 0.9062, auc: 0.9717, precision: 0.9677, recall: 0.8571
# 2019-03-18T11:00:31.390573, step: 193, loss: 0.2524837255477905, acc: 0.9141, auc: 0.9653, precision: 0.8971, recall: 0.9385
# 2019-03-18T11:00:40.768898, step: 194, loss: 0.16979368031024933, acc: 0.9453, auc: 0.9827, precision: 0.9744, recall: 0.9383
# 2019-03-18T11:00:50.187413, step: 195, loss: 0.28324684500694275, acc: 0.8828, auc: 0.9509, precision: 0.84, recall: 0.8571
# 2019-03-18T11:00:59.324588, step: 196, loss: 0.23965930938720703, acc: 0.8828, auc: 0.9787, precision: 0.9831, recall: 0.8056
# 2019-03-18T11:01:09.430425, step: 197, loss: 0.2156280279159546, acc: 0.8828, auc: 0.9794, precision: 0.9672, recall: 0.8194
# 2019-03-18T11:01:19.313259, step: 198, loss: 0.1900942623615265, acc: 0.9453, auc: 0.98, precision: 0.9412, recall: 0.9231
# 2019-03-18T11:01:29.056658, step: 199, loss: 0.3174722194671631, acc: 0.875, auc: 0.9464, precision: 0.8448, recall: 0.875
# 2019-03-18T11:01:40.436902, step: 200, loss: 0.17596949636936188, acc: 0.9297, auc: 0.9893, precision: 0.9091, recall: 0.9524
#
# Evaluation:
# 2019-03-18T11:07:37.026131, step: 200, loss: 0.29940167910013443, acc: 0.8661846153846153, auc: 0.9494589743589744, precision: 0.9175923076923076, recall: 0.808169230769231
# 2019-03-18T11:07:46.246752, step: 201, loss: 0.30663496255874634, acc: 0.875, auc: 0.9445, precision: 0.9322, recall: 0.8209
# 2019-03-18T11:07:55.726555, step: 202, loss: 0.2244674563407898, acc: 0.8906, auc: 0.9725, precision: 0.9259, recall: 0.8333
# 2019-03-18T11:08:05.236698, step: 203, loss: 0.3534286618232727, acc: 0.8594, auc: 0.945, precision: 0.9661, recall: 0.7808
# 2019-03-18T11:08:14.400608, step: 204, loss: 0.3248160779476166, acc: 0.8359, auc: 0.9416, precision: 0.8889, recall: 0.8
# 2019-03-18T11:08:23.839809, step: 205, loss: 0.12460999190807343, acc: 0.9453, auc: 0.9926, precision: 1.0, recall: 0.9028
# 2019-03-18T11:08:32.818867, step: 206, loss: 0.26003196835517883, acc: 0.8906, auc: 0.9741, precision: 0.8684, recall: 0.9429
# 2019-03-18T11:08:42.932792, step: 207, loss: 0.2518002390861511, acc: 0.8984, auc: 0.977, precision: 0.8571, recall: 0.9706
# 2019-03-18T11:08:52.153918, step: 208, loss: 0.2822069525718689, acc: 0.8828, auc: 0.9614, precision: 0.8636, recall: 0.9048
# 2019-03-18T11:09:01.923435, step: 209, loss: 0.1758778691291809, acc: 0.8984, auc: 0.9921, precision: 0.9851, recall: 0.8462
# 2019-03-18T11:09:10.951195, step: 210, loss: 0.17982198297977448, acc: 0.9219, auc: 0.9849, precision: 0.9825, recall: 0.8615
# 2019-03-18T11:09:20.679759, step: 211, loss: 0.2625105381011963, acc: 0.8828, auc: 0.9561, precision: 0.9153, recall: 0.8438
# 2019-03-18T11:09:29.963104, step: 212, loss: 0.18903934955596924, acc: 0.9297, auc: 0.9788, precision: 0.9792, recall: 0.8545
# 2019-03-18T11:09:38.667226, step: 213, loss: 0.2142075151205063, acc: 0.9141, auc: 0.9712, precision: 0.9077, recall: 0.9219
# 2019-03-18T11:09:47.945608, step: 214, loss: 0.16642457246780396, acc: 0.9297, auc: 0.9841, precision: 0.9333, recall: 0.918
# 2019-03-18T11:09:57.346066, step: 215, loss: 0.28545987606048584, acc: 0.8516, auc: 0.9477, precision: 0.9032, recall: 0.8116
# 2019-03-18T11:10:06.404442, step: 216, loss: 0.24766583740711212, acc: 0.8984, auc: 0.9614, precision: 0.9167, recall: 0.873
# 2019-03-18T11:10:15.760240, step: 217, loss: 0.22474491596221924, acc: 0.9062, auc: 0.9707, precision: 0.931, recall: 0.871
# 2019-03-18T11:10:25.431193, step: 218, loss: 0.299732506275177, acc: 0.8906, auc: 0.939, precision: 0.8654, recall: 0.8654
# 2019-03-18T11:10:34.464799, step: 219, loss: 0.1990009844303131, acc: 0.9141, auc: 0.9785, precision: 0.9344, recall: 0.8906
# 2019-03-18T11:10:44.099676, step: 220, loss: 0.210301473736763, acc: 0.9297, auc: 0.9729, precision: 0.9623, recall: 0.8793
# 2019-03-18T11:10:53.635418, step: 221, loss: 0.13937228918075562, acc: 0.9375, auc: 0.9893, precision: 0.9672, recall: 0.9077
# 2019-03-18T11:11:03.992775, step: 222, loss: 0.1878933161497116, acc: 0.9375, auc: 0.9819, precision: 0.9167, recall: 0.9706
# 2019-03-18T11:11:14.039825, step: 223, loss: 0.14150923490524292, acc: 0.9297, auc: 0.9912, precision: 0.95, recall: 0.9048
# 2019-03-18T11:11:23.906022, step: 224, loss: 0.24153001606464386, acc: 0.8906, auc: 0.9616, precision: 0.9231, recall: 0.8276
# 2019-03-18T11:11:34.080642, step: 225, loss: 0.25299012660980225, acc: 0.8984, auc: 0.9583, precision: 0.918, recall: 0.875
# 2019-03-18T11:11:43.363218, step: 226, loss: 0.2723904252052307, acc: 0.9062, auc: 0.9564, precision: 0.9661, recall: 0.8507
# 2019-03-18T11:11:52.528270, step: 227, loss: 0.15757045149803162, acc: 0.9375, auc: 0.9853, precision: 0.9344, recall: 0.9344
# 2019-03-18T11:12:01.361251, step: 228, loss: 0.19665895402431488, acc: 0.9219, auc: 0.9758, precision: 0.9524, recall: 0.8955
# 2019-03-18T11:12:10.862693, step: 229, loss: 0.1170274168252945, acc: 0.9766, auc: 0.991, precision: 0.9701, recall: 0.9848
# 2019-03-18T11:12:20.067298, step: 230, loss: 0.20021936297416687, acc: 0.9453, auc: 0.9771, precision: 0.9385, recall: 0.9531
# 2019-03-18T11:12:29.351209, step: 231, loss: 0.183310866355896, acc: 0.9453, auc: 0.981, precision: 0.931, recall: 0.9474
# 2019-03-18T11:12:39.213855, step: 232, loss: 0.16285911202430725, acc: 0.9141, auc: 0.9893, precision: 0.9655, recall: 0.8615
# 2019-03-18T11:12:48.668887, step: 233, loss: 0.2333706021308899, acc: 0.9062, auc: 0.9719, precision: 0.9423, recall: 0.8448
# 2019-03-18T11:12:58.110921, step: 234, loss: 0.19006389379501343, acc: 0.8984, auc: 0.9813, precision: 0.9524, recall: 0.8571
# 2019-03-18T11:13:07.477229, step: 235, loss: 0.16447937488555908, acc: 0.8984, auc: 0.9869, precision: 0.9677, recall: 0.8451
# 2019-03-18T11:13:17.155428, step: 236, loss: 0.2223750352859497, acc: 0.9062, auc: 0.9712, precision: 0.8955, recall: 0.9231
# 2019-03-18T11:13:26.430898, step: 237, loss: 0.27396443486213684, acc: 0.8984, auc: 0.9752, precision: 0.8382, recall: 0.9661
# 2019-03-18T11:13:35.791955, step: 238, loss: 0.38348203897476196, acc: 0.8672, auc: 0.9656, precision: 0.8, recall: 0.9846
# 2019-03-18T11:13:44.709987, step: 239, loss: 0.2520262598991394, acc: 0.875, auc: 0.9745, precision: 1.0, recall: 0.7778
# 2019-03-18T11:13:54.445147, step: 240, loss: 0.3578265309333801, acc: 0.8438, auc: 0.9748, precision: 1.0, recall: 0.697
# 2019-03-18T11:14:03.850921, step: 241, loss: 0.31081825494766235, acc: 0.7969, auc: 0.9993, precision: 1.0, recall: 0.6119
# 2019-03-18T11:14:12.981403, step: 242, loss: 0.24328619241714478, acc: 0.8906, auc: 0.9759, precision: 0.9706, recall: 0.8462
# 2019-03-18T11:14:22.297933, step: 243, loss: 0.24903614819049835, acc: 0.8906, auc: 0.9718, precision: 0.8649, recall: 0.9412
# 2019-03-18T11:14:31.694393, step: 244, loss: 0.3693750202655792, acc: 0.8594, auc: 0.9731, precision: 0.8, recall: 0.9697
# 2019-03-18T11:14:41.115210, step: 245, loss: 0.4397905170917511, acc: 0.8281, auc: 0.9696, precision: 0.7317, recall: 1.0
# 2019-03-18T11:14:49.762077, step: 246, loss: 0.3055890202522278, acc: 0.8906, auc: 0.9653, precision: 0.8442, recall: 0.9701
# 2019-03-18T11:14:59.413244, step: 247, loss: 0.22070929408073425, acc: 0.9297, auc: 0.9831, precision: 0.9231, recall: 0.9057
# 2019-03-18T11:15:09.119866, step: 248, loss: 0.22190073132514954, acc: 0.8984, auc: 0.9763, precision: 0.975, recall: 0.7647
# 2019-03-18T11:15:17.993466, step: 249, loss: 0.3821468651294708, acc: 0.7891, auc: 0.9658, precision: 1.0, recall: 0.5179
# 2019-03-18T11:15:26.979986, step: 250, loss: 0.4261128902435303, acc: 0.7109, auc: 0.9806, precision: 1.0, recall: 0.4559
# 2019-03-18T11:15:37.426804, step: 251, loss: 0.3933037221431732, acc: 0.7266, auc: 0.9778, precision: 0.973, recall: 0.5143
# 2019-03-18T11:15:46.886720, step: 252, loss: 0.3506282567977905, acc: 0.8203, auc: 0.9482, precision: 0.9773, recall: 0.6615
# 2019-03-18T11:15:55.904463, step: 253, loss: 0.21213437616825104, acc: 0.9375, auc: 0.9939, precision: 0.9825, recall: 0.8889
# 2019-03-18T11:16:04.950147, step: 254, loss: 0.2559686601161957, acc: 0.9375, auc: 0.9858, precision: 0.9, recall: 0.9844
# 2019-03-18T11:16:14.229056, step: 255, loss: 0.30067604780197144, acc: 0.9141, auc: 0.9956, precision: 0.8514, recall: 1.0
# 2019-03-18T11:16:23.130345, step: 256, loss: 0.3087919354438782, acc: 0.8906, auc: 0.9681, precision: 0.8571, recall: 0.9565
# 2019-03-18T11:16:31.978023, step: 257, loss: 0.248409241437912, acc: 0.9141, auc: 0.9816, precision: 0.9079, recall: 0.9452
# 2019-03-18T11:16:41.313956, step: 258, loss: 0.22268018126487732, acc: 0.9219, auc: 0.9743, precision: 0.9333, recall: 0.9333
# 2019-03-18T11:16:51.009965, step: 259, loss: 0.1812012493610382, acc: 0.9688, auc: 0.9939, precision: 0.9825, recall: 0.9492
# 2019-03-18T11:16:59.982358, step: 260, loss: 0.21510189771652222, acc: 0.9219, auc: 0.9659, precision: 1.0, recall: 0.7872
# 2019-03-18T11:17:08.993997, step: 261, loss: 0.2413550317287445, acc: 0.8906, auc: 0.9711, precision: 0.9655, recall: 0.8235
# 2019-03-18T11:17:18.034302, step: 262, loss: 0.27628424763679504, acc: 0.8672, auc: 0.9593, precision: 0.9535, recall: 0.7321
# 2019-03-18T11:17:27.362764, step: 263, loss: 0.3370411992073059, acc: 0.8516, auc: 0.9449, precision: 0.9184, recall: 0.75
# 2019-03-18T11:17:37.087518, step: 264, loss: 0.26477473974227905, acc: 0.8828, auc: 0.9599, precision: 0.9608, recall: 0.7903
# 2019-03-18T11:17:46.358935, step: 265, loss: 0.14633291959762573, acc: 0.9141, auc: 0.9906, precision: 0.96, recall: 0.8421
# 2019-03-18T11:17:56.118105, step: 266, loss: 0.1703004390001297, acc: 0.9531, auc: 0.9802, precision: 0.9231, recall: 1.0
# 2019-03-18T11:18:06.016005, step: 267, loss: 0.25716307759284973, acc: 0.9219, auc: 0.9677, precision: 0.9062, recall: 0.9355
# 2019-03-18T11:18:15.181050, step: 268, loss: 0.19477656483650208, acc: 0.9375, auc: 0.9874, precision: 0.8871, recall: 0.9821
# 2019-03-18T11:18:24.472704, step: 269, loss: 0.25023549795150757, acc: 0.9219, auc: 0.9687, precision: 0.9048, recall: 0.9344
# 2019-03-18T11:18:34.093233, step: 270, loss: 0.25257840752601624, acc: 0.8828, auc: 0.9634, precision: 0.8667, recall: 0.8814
# 2019-03-18T11:18:43.573352, step: 271, loss: 0.2736230492591858, acc: 0.8594, auc: 0.9629, precision: 0.9412, recall: 0.7619
# 2019-03-18T11:18:53.127903, step: 272, loss: 0.26999208331108093, acc: 0.8594, auc: 0.9615, precision: 0.9206, recall: 0.8169
# 2019-03-18T11:19:02.412859, step: 273, loss: 0.2563838064670563, acc: 0.9219, auc: 0.9616, precision: 0.9559, recall: 0.9028
# 2019-03-18T11:19:12.117102, step: 274, loss: 0.3660033345222473, acc: 0.8672, auc: 0.9313, precision: 0.9153, recall: 0.8182
# 2019-03-18T11:19:21.301784, step: 275, loss: 0.28709936141967773, acc: 0.8984, auc: 0.9505, precision: 0.9091, recall: 0.8621
# 2019-03-18T11:19:30.655886, step: 276, loss: 0.2597886025905609, acc: 0.8984, auc: 0.9666, precision: 0.8696, recall: 0.9375
# 2019-03-18T11:19:40.592896, step: 277, loss: 0.29316508769989014, acc: 0.9219, auc: 0.9678, precision: 0.8657, recall: 0.9831
# 2019-03-18T11:19:49.596627, step: 278, loss: 0.26446598768234253, acc: 0.9297, auc: 0.9665, precision: 0.8939, recall: 0.9672
# 2019-03-18T11:19:58.900769, step: 279, loss: 0.18009978532791138, acc: 0.9141, auc: 0.9841, precision: 0.9828, recall: 0.8507
# 2019-03-18T11:20:08.274819, step: 280, loss: 0.21108682453632355, acc: 0.9297, auc: 0.976, precision: 1.0, recall: 0.8657
# 2019-03-18T11:20:17.924799, step: 281, loss: 0.2074480801820755, acc: 0.9297, auc: 0.977, precision: 0.9821, recall: 0.873
# 2019-03-18T11:20:27.349823, step: 282, loss: 0.2709125876426697, acc: 0.8828, auc: 0.9565, precision: 0.9623, recall: 0.7969
# 2019-03-18T11:20:36.452127, step: 283, loss: 0.28922027349472046, acc: 0.8594, auc: 0.9522, precision: 0.9375, recall: 0.75
# 2019-03-18T11:20:46.040933, step: 284, loss: 0.1850011944770813, acc: 0.9453, auc: 0.9763, precision: 0.9825, recall: 0.9032
# 2019-03-18T11:20:55.629796, step: 285, loss: 0.23200801014900208, acc: 0.9062, auc: 0.9692, precision: 0.9048, recall: 0.9048
# 2019-03-18T11:21:04.883837, step: 286, loss: 0.2320551723241806, acc: 0.9141, auc: 0.9761, precision: 0.8841, recall: 0.9531
# 2019-03-18T11:21:14.340885, step: 287, loss: 0.19031932950019836, acc: 0.9375, auc: 0.9804, precision: 0.9677, recall: 0.9091
# 2019-03-18T11:21:24.026076, step: 288, loss: 0.19368815422058105, acc: 0.9297, auc: 0.9764, precision: 0.9552, recall: 0.9143
# 2019-03-18T11:21:32.844828, step: 289, loss: 0.23971401154994965, acc: 0.9219, auc: 0.9623, precision: 0.9444, recall: 0.8793
# 2019-03-18T11:21:42.265324, step: 290, loss: 0.2783784568309784, acc: 0.9062, auc: 0.95, precision: 0.9483, recall: 0.8594
# 2019-03-18T11:21:51.710971, step: 291, loss: 0.20978331565856934, acc: 0.9141, auc: 0.9779, precision: 0.98, recall: 0.8305
# 2019-03-18T11:22:01.648836, step: 292, loss: 0.24122846126556396, acc: 0.8984, auc: 0.9639, precision: 0.9545, recall: 0.863
# 2019-03-18T11:22:11.128223, step: 293, loss: 0.2447456419467926, acc: 0.9141, auc: 0.9643, precision: 0.9104, recall: 0.9242
# 2019-03-18T11:22:20.454925, step: 294, loss: 0.17309457063674927, acc: 0.9297, auc: 0.9814, precision: 0.9194, recall: 0.9344
# 2019-03-18T11:22:29.862866, step: 295, loss: 0.1730945110321045, acc: 0.9297, auc: 0.9827, precision: 0.9355, recall: 0.9206
# 2019-03-18T11:22:39.296236, step: 296, loss: 0.21473753452301025, acc: 0.8828, auc: 0.9729, precision: 0.9016, recall: 0.8594
# 2019-03-18T11:22:48.480353, step: 297, loss: 0.16840001940727234, acc: 0.9062, auc: 0.9879, precision: 0.9836, recall: 0.8451
# 2019-03-18T11:22:57.967035, step: 298, loss: 0.2070436179637909, acc: 0.9297, auc: 0.9736, precision: 0.9804, recall: 0.8621
# 2019-03-18T11:23:07.563143, step: 299, loss: 0.21620211005210876, acc: 0.9062, auc: 0.9709, precision: 0.9231, recall: 0.8955
# 2019-03-18T11:23:16.894406, step: 300, loss: 0.1603756546974182, acc: 0.9375, auc: 0.9909, precision: 0.9474, recall: 0.9153
#
# Evaluation:
# 2019-03-18T11:29:16.945185, step: 300, loss: 0.29809413353602093, acc: 0.879997435897436, auc: 0.9508333333333334, precision: 0.8900589743589745, recall: 0.8702282051282052
# 2019-03-18T11:29:26.073372, step: 301, loss: 0.3513035178184509, acc: 0.8984, auc: 0.9308, precision: 0.9138, recall: 0.8689
# 2019-03-18T11:29:35.602300, step: 302, loss: 0.27783018350601196, acc: 0.8984, auc: 0.9567, precision: 0.8846, recall: 0.9452
# 2019-03-18T11:29:44.972623, step: 303, loss: 0.18721085786819458, acc: 0.9219, auc: 0.9856, precision: 1.0, recall: 0.8611
# 2019-03-18T11:29:54.258600, step: 304, loss: 0.21646299958229065, acc: 0.9062, auc: 0.9783, precision: 0.9692, recall: 0.863
# 2019-03-18T11:30:03.952297, step: 305, loss: 0.1878250688314438, acc: 0.9375, auc: 0.9763, precision: 0.9344, recall: 0.9344
# 2019-03-18T11:30:13.353215, step: 306, loss: 0.2547404170036316, acc: 0.9219, auc: 0.9573, precision: 0.9344, recall: 0.9048
# 2019-03-18T11:30:22.614968, step: 307, loss: 0.27211838960647583, acc: 0.8828, auc: 0.9595, precision: 0.9074, recall: 0.8305
# 2019-03-18T11:30:32.096796, step: 308, loss: 0.2222478687763214, acc: 0.9062, auc: 0.9722, precision: 0.9123, recall: 0.8814
# 2019-03-18T11:30:43.051051, step: 309, loss: 0.16631051898002625, acc: 0.9219, auc: 0.9853, precision: 0.9143, recall: 0.9412
# 2019-03-18T11:30:53.584619, step: 310, loss: 0.15369680523872375, acc: 0.9453, auc: 0.9858, precision: 0.9841, recall: 0.9118
# 2019-03-18T11:31:03.056080, step: 311, loss: 0.20419207215309143, acc: 0.9297, auc: 0.9739, precision: 0.9492, recall: 0.9032
# 2019-03-18T11:31:13.294146, step: 312, loss: 0.18171349167823792, acc: 0.9375, auc: 0.9821, precision: 0.9206, recall: 0.9508
# start training model
# 2019-03-18T11:31:23.737717, step: 313, loss: 0.13875946402549744, acc: 0.9609, auc: 0.985, precision: 0.9848, recall: 0.942
# 2019-03-18T11:31:34.166247, step: 314, loss: 0.11083602905273438, acc: 0.9688, auc: 0.9949, precision: 0.9848, recall: 0.9559
# 2019-03-18T11:31:43.836858, step: 315, loss: 0.108390673995018, acc: 0.9609, auc: 0.9961, precision: 0.9688, recall: 0.9538
# 2019-03-18T11:31:56.128241, step: 316, loss: 0.14722199738025665, acc: 0.9531, auc: 0.9886, precision: 0.9423, recall: 0.9423
# 2019-03-18T11:32:07.168821, step: 317, loss: 0.19175155460834503, acc: 0.9297, auc: 0.9799, precision: 0.9833, recall: 0.8806
# 2019-03-18T11:32:17.202538, step: 318, loss: 0.10970824956893921, acc: 0.9531, auc: 0.9958, precision: 0.9836, recall: 0.9231
# 2019-03-18T11:32:27.827723, step: 319, loss: 0.14383099973201752, acc: 0.9453, auc: 0.988, precision: 0.9538, recall: 0.9394
# 2019-03-18T11:32:38.230521, step: 320, loss: 0.09352429211139679, acc: 0.9766, auc: 0.9946, precision: 0.9857, recall: 0.9718
# 2019-03-18T11:32:50.837623, step: 321, loss: 0.09928993880748749, acc: 0.9688, auc: 0.9933, precision: 1.0, recall: 0.9429
# 2019-03-18T11:33:03.654871, step: 322, loss: 0.1133359894156456, acc: 0.9453, auc: 0.9934, precision: 0.9839, recall: 0.9104
# 2019-03-18T11:33:15.974150, step: 323, loss: 0.10236900299787521, acc: 0.9844, auc: 0.9949, precision: 0.9697, recall: 1.0
# 2019-03-18T11:33:26.270049, step: 324, loss: 0.11922883242368698, acc: 0.9531, auc: 0.9899, precision: 0.9701, recall: 0.942
# 2019-03-18T11:33:37.122509, step: 325, loss: 0.11595828086137772, acc: 0.9453, auc: 0.9936, precision: 0.9508, recall: 0.9355
# 2019-03-18T11:33:47.675604, step: 326, loss: 0.21981817483901978, acc: 0.9297, auc: 0.9677, precision: 0.9298, recall: 0.9138
# 2019-03-18T11:33:57.916801, step: 327, loss: 0.2860668897628784, acc: 0.9062, auc: 0.956, precision: 0.8814, recall: 0.9123
# 2019-03-18T11:34:07.471118, step: 328, loss: 0.14170941710472107, acc: 0.9688, auc: 0.9788, precision: 1.0, recall: 0.9365
# 2019-03-18T11:34:18.103466, step: 329, loss: 0.07353039085865021, acc: 0.9688, auc: 0.9985, precision: 1.0, recall: 0.9394
# 2019-03-18T11:34:28.198785, step: 330, loss: 0.062399085611104965, acc: 0.9844, auc: 0.9993, precision: 1.0, recall: 0.9661
# 2019-03-18T11:34:38.133314, step: 331, loss: 0.09350202232599258, acc: 0.9297, auc: 0.9961, precision: 0.9831, recall: 0.8788
# 2019-03-18T11:34:48.849806, step: 332, loss: 0.09522168338298798, acc: 0.9609, auc: 0.9968, precision: 0.9437, recall: 0.9853
# 2019-03-18T11:34:58.895884, step: 333, loss: 0.07571461796760559, acc: 0.9688, auc: 0.9975, precision: 1.0, recall: 0.9429
# 2019-03-18T11:35:09.171211, step: 334, loss: 0.1879483312368393, acc: 0.9453, auc: 0.9872, precision: 0.918, recall: 0.9655
# 2019-03-18T11:35:18.964518, step: 335, loss: 0.11967717111110687, acc: 0.9453, auc: 0.9929, precision: 0.9344, recall: 0.95
# 2019-03-18T11:35:29.251563, step: 336, loss: 0.21861831843852997, acc: 0.9141, auc: 0.977, precision: 0.9365, recall: 0.8939
# 2019-03-18T11:35:38.986438, step: 337, loss: 0.04324861615896225, acc: 0.9844, auc: 1.0, precision: 1.0, recall: 0.9697
# 2019-03-18T11:35:49.214226, step: 338, loss: 0.15746167302131653, acc: 0.9297, auc: 0.9865, precision: 0.9722, recall: 0.9091
# 2019-03-18T11:35:59.256185, step: 339, loss: 0.12520544230937958, acc: 0.9688, auc: 0.9905, precision: 0.9683, recall: 0.9683
# 2019-03-18T11:36:08.539804, step: 340, loss: 0.1816600263118744, acc: 0.9219, auc: 0.9863, precision: 0.9531, recall: 0.8971
# 2019-03-18T11:36:18.227316, step: 341, loss: 0.08774921298027039, acc: 0.9609, auc: 0.9958, precision: 0.9844, recall: 0.9403
# 2019-03-18T11:36:28.390841, step: 342, loss: 0.1499919891357422, acc: 0.9375, auc: 0.9856, precision: 0.9516, recall: 0.9219
# 2019-03-18T11:36:38.591633, step: 343, loss: 0.16729742288589478, acc: 0.9297, auc: 0.987, precision: 1.0, recall: 0.8767
# 2019-03-18T11:36:49.173343, step: 344, loss: 0.1691630482673645, acc: 0.9375, auc: 0.9866, precision: 0.9394, recall: 0.9394
# 2019-03-18T11:36:59.882918, step: 345, loss: 0.21264135837554932, acc: 0.9453, auc: 0.9795, precision: 0.9275, recall: 0.9697
# 2019-03-18T11:37:11.557964, step: 346, loss: 0.11645150184631348, acc: 0.9531, auc: 0.9953, precision: 0.918, recall: 0.9825
# 2019-03-18T11:37:24.171946, step: 347, loss: 0.12995243072509766, acc: 0.9531, auc: 0.9868, precision: 0.9839, recall: 0.9242
# 2019-03-18T11:37:34.809448, step: 348, loss: 0.17766860127449036, acc: 0.9219, auc: 0.9819, precision: 0.9464, recall: 0.8833
# 2019-03-18T11:37:47.119713, step: 349, loss: 0.18842855095863342, acc: 0.9375, auc: 0.9836, precision: 0.9825, recall: 0.8889
# 2019-03-18T11:37:58.049885, step: 350, loss: 0.09315130114555359, acc: 0.9688, auc: 0.9963, precision: 0.9846, recall: 0.9552
# 2019-03-18T11:38:07.348251, step: 351, loss: 0.11339236795902252, acc: 0.9609, auc: 0.9902, precision: 0.9821, recall: 0.9322
# 2019-03-18T11:38:17.671154, step: 352, loss: 0.16564810276031494, acc: 0.9375, auc: 0.9802, precision: 0.9508, recall: 0.9206
# 2019-03-18T11:38:26.936598, step: 353, loss: 0.10260210186243057, acc: 0.9766, auc: 0.9914, precision: 0.9701, recall: 0.9848
# 2019-03-18T11:38:36.212451, step: 354, loss: 0.1325727105140686, acc: 0.9453, auc: 0.9914, precision: 0.9688, recall: 0.9254
# 2019-03-18T11:38:45.444379, step: 355, loss: 0.06566116213798523, acc: 0.9766, auc: 0.9985, precision: 0.9726, recall: 0.9861
# ...
# 2019-03-18T12:13:00.304844, step: 499, loss: 0.1230832040309906, acc: 0.9453, auc: 0.998, precision: 1.0, recall: 0.8871
# 2019-03-18T12:13:10.762711, step: 500, loss: 0.040477145463228226, acc: 0.9922, auc: 0.999, precision: 1.0, recall: 0.9859
#
# Evaluation:
# 2019-03-18T12:19:32.144618, step: 500, loss: 0.5236671559321575, acc: 0.8746, auc: 0.9464128205128203, precision: 0.8420025641025642, recall: 0.9252820512820514
# 2019-03-18T12:19:42.316597, step: 501, loss: 0.06200036033987999, acc: 0.9688, auc: 0.999, precision: 0.9531, recall: 0.9839
# 2019-03-18T12:19:52.687189, step: 502, loss: 0.11317858099937439, acc: 0.9688, auc: 0.9993, precision: 0.9394, recall: 1.0
# 2019-03-18T12:20:02.329690, step: 503, loss: 0.08474566042423248, acc: 0.9688, auc: 0.998, precision: 0.9492, recall: 0.9825
# 2019-03-18T12:20:11.805676, step: 504, loss: 0.05391063168644905, acc: 0.9844, auc: 0.998, precision: 0.9841, recall: 0.9841
# 2019-03-18T12:20:21.846370, step: 505, loss: 0.146020770072937, acc: 0.9609, auc: 0.9956, precision: 1.0, recall: 0.9167
# 2019-03-18T12:20:32.336439, step: 506, loss: 0.155074805021286, acc: 0.9375, auc: 0.9875, precision: 0.9851, recall: 0.9041
# 2019-03-18T12:20:42.860592, step: 507, loss: 0.1370777189731598, acc: 0.9609, auc: 0.984, precision: 0.971, recall: 0.9571
# 2019-03-18T12:20:53.438516, step: 508, loss: 0.09789043664932251, acc: 0.9609, auc: 0.9975, precision: 0.9444, recall: 0.9855
# 2019-03-18T12:21:03.615685, step: 509, loss: 0.07448437809944153, acc: 0.9766, auc: 0.9975, precision: 0.9661, recall: 0.9828
# 2019-03-18T12:21:13.645660, step: 510, loss: 0.07929055392742157, acc: 0.9609, auc: 0.9971, precision: 0.9516, recall: 0.9672
# 2019-03-18T12:21:24.821823, step: 511, loss: 0.048645880073308945, acc: 0.9766, auc: 0.9988, precision: 0.9848, recall: 0.9701
# 2019-03-18T12:21:35.133269, step: 512, loss: 0.07479841262102127, acc: 0.9688, auc: 0.9976, precision: 0.9846, recall: 0.9552
# 2019-03-18T12:21:45.372167, step: 513, loss: 0.0945587009191513, acc: 0.9531, auc: 0.997, precision: 1.0, recall: 0.8966
# 2019-03-18T12:21:55.939222, step: 514, loss: 0.08344605565071106, acc: 0.9453, auc: 0.9971, precision: 0.9836, recall: 0.9091
# 2019-03-18T12:22:05.930747, step: 515, loss: 0.06919020414352417, acc: 0.9609, auc: 0.9983, precision: 1.0, recall: 0.9296
# 2019-03-18T12:22:15.974368, step: 516, loss: 0.08959439396858215, acc: 0.9844, auc: 0.9973, precision: 0.9649, recall: 1.0
# 2019-03-18T12:22:26.350506, step: 517, loss: 0.07246319204568863, acc: 0.9688, auc: 0.9978, precision: 0.9661, recall: 0.9661
# 2019-03-18T12:22:36.038791, step: 518, loss: 0.10526683181524277, acc: 0.9844, auc: 0.9894, precision: 0.9857, recall: 0.9857
# 2019-03-18T12:22:46.711688, step: 519, loss: 0.07988190650939941, acc: 0.9688, auc: 0.996, precision: 0.9857, recall: 0.9583
# 2019-03-18T12:22:56.818290, step: 520, loss: 0.05485094338655472, acc: 0.9922, auc: 0.9971, precision: 0.9848, recall: 1.0
# 2019-03-18T12:23:08.668288, step: 521, loss: 0.03507208079099655, acc: 0.9922, auc: 1.0, precision: 1.0, recall: 0.9839
# 2019-03-18T12:23:18.865269, step: 522, loss: 0.02352309599518776, acc: 1.0, auc: 1.0, precision: 1.0, recall: 1.0
# 2019-03-18T12:23:28.589112, step: 523, loss: 0.0785997211933136, acc: 0.9688, auc: 0.9998, precision: 1.0, recall: 0.9437
# 2019-03-18T12:23:39.007002, step: 524, loss: 0.04820781201124191, acc: 0.9922, auc: 0.9998, precision: 1.0, recall: 0.9831
# 2019-03-18T12:23:49.757516, step: 525, loss: 0.04103095829486847, acc: 0.9844, auc: 0.999, precision: 1.0, recall: 0.9677
# 2019-03-18T12:24:00.605424, step: 526, loss: 0.07399210333824158, acc: 0.9844, auc: 0.9985, precision: 0.9667, recall: 1.0
# 2019-03-18T12:24:13.003790, step: 527, loss: 0.1614212840795517, acc: 0.9531, auc: 0.9856, precision: 0.9296, recall: 0.9851
# 2019-03-18T12:24:24.590595, step: 528, loss: 0.07014626264572144, acc: 0.9688, auc: 0.9971, precision: 0.9833, recall: 0.9516
# 2019-03-18T12:24:34.852901, step: 529, loss: 0.0881062000989914, acc: 0.9688, auc: 0.9951, precision: 1.0, recall: 0.942
# 2019-03-18T12:24:44.929999, step: 530, loss: 0.05412882938981056, acc: 0.9688, auc: 0.9978, precision: 0.9844, recall: 0.9545
# 2019-03-18T12:24:55.091576, step: 531, loss: 0.04312771558761597, acc: 0.9766, auc: 0.9995, precision: 0.9861, recall: 0.9726
# 2019-03-18T12:25:04.931221, step: 532, loss: 0.07806996256113052, acc: 0.9922, auc: 0.9973, precision: 0.9828, recall: 1.0
# 2019-03-18T12:25:14.574702, step: 533, loss: 0.11918992549180984, acc: 0.9688, auc: 0.9895, precision: 0.9836, recall: 0.9524
# 2019-03-18T12:25:24.929599, step: 534, loss: 0.03532719239592552, acc: 0.9922, auc: 0.9995, precision: 0.9846, recall: 1.0
# 2019-03-18T12:25:34.673737, step: 535, loss: 0.13616620004177094, acc: 0.9531, auc: 0.9899, precision: 0.9706, recall: 0.9429
# 2019-03-18T12:25:43.741911, step: 536, loss: 0.08601401746273041, acc: 0.9844, auc: 0.9914, precision: 1.0, recall: 0.9661
# 2019-03-18T12:25:53.474594, step: 537, loss: 0.07805021107196808, acc: 0.9688, auc: 0.995, precision: 1.0, recall: 0.9459
# 2019-03-18T12:26:02.939021, step: 538, loss: 0.06008172780275345, acc: 0.9766, auc: 0.9988, precision: 0.9667, recall: 0.9831
# 2019-03-18T12:26:12.344601, step: 539, loss: 0.030224405229091644, acc: 0.9922, auc: 1.0, precision: 0.9848, recall: 1.0
# 2019-03-18T12:26:21.598260, step: 540, loss: 0.05283138528466225, acc: 0.9844, auc: 0.9976, precision: 0.9844, recall: 0.9844
# 2019-03-18T12:26:31.166233, step: 541, loss: 0.0932779461145401, acc: 0.9766, auc: 0.9912, precision: 1.0, recall: 0.9545
# 2019-03-18T12:26:40.677160, step: 542, loss: 0.07216347008943558, acc: 0.9766, auc: 0.9963, precision: 0.9759, recall: 0.9878
# 2019-03-18T12:26:49.843780, step: 543, loss: 0.03444188833236694, acc: 0.9922, auc: 0.9998, precision: 0.9839, recall: 1.0
# 2019-03-18T12:26:59.158572, step: 544, loss: 0.04399220645427704, acc: 0.9844, auc: 0.999, precision: 1.0, recall: 0.9636
# 2019-03-18T12:27:09.018785, step: 545, loss: 0.06431347876787186, acc: 0.9531, auc: 0.9998, precision: 1.0, recall: 0.9077
# 2019-03-18T12:27:17.844251, step: 546, loss: 0.055945251137018204, acc: 0.9844, auc: 0.999, precision: 0.971, recall: 1.0
# 2019-03-18T12:27:26.964822, step: 547, loss: 0.11535388976335526, acc: 0.9688, auc: 0.985, precision: 1.0, recall: 0.9412
# 2019-03-18T12:27:36.030951, step: 548, loss: 0.0596478171646595, acc: 0.9766, auc: 0.9985, precision: 0.9839, recall: 0.9683
# 2019-03-18T12:27:45.694867, step: 549, loss: 0.08261255919933319, acc: 0.9766, auc: 0.9953, precision: 0.9661, recall: 0.9828
# 2019-03-18T12:27:55.120006, step: 550, loss: 0.04860268905758858, acc: 0.9922, auc: 0.998, precision: 1.0, recall: 0.9857
# 2019-03-18T12:28:04.501535, step: 551, loss: 0.0870044156908989, acc: 0.9844, auc: 0.9922, precision: 1.0, recall: 0.9667
# 2019-03-18T12:28:14.089201, step: 552, loss: 0.01990378275513649, acc: 0.9922, auc: 1.0, precision: 1.0, recall: 0.9831
# 2019-03-18T12:28:23.618009, step: 553, loss: 0.12180905044078827, acc: 0.9844, auc: 0.9821, precision: 0.9853, recall: 0.9853
# 2019-03-18T12:28:32.941572, step: 554, loss: 0.03520483523607254, acc: 0.9922, auc: 0.9993, precision: 1.0, recall: 0.9831
# 2019-03-18T12:28:42.245044, step: 555, loss: 0.09321334958076477, acc: 0.9688, auc: 0.9936, precision: 0.9848, recall: 0.9559
# 2019-03-18T12:28:51.975035, step: 556, loss: 0.042966220527887344, acc: 0.9922, auc: 0.9998, precision: 0.9833, recall: 1.0
# 2019-03-18T12:29:00.672194, step: 557, loss: 0.08192670345306396, acc: 0.9766, auc: 0.999, precision: 0.9565, recall: 1.0
# 2019-03-18T12:29:09.999935, step: 558, loss: 0.06808507442474365, acc: 0.9766, auc: 0.9961, precision: 0.9836, recall: 0.9677
# 2019-03-18T12:29:19.124015, step: 559, loss: 0.04312456026673317, acc: 0.9688, auc: 1.0, precision: 1.0, recall: 0.9355
# 2019-03-18T12:29:28.934917, step: 560, loss: 0.028797117993235588, acc: 0.9922, auc: 0.9998, precision: 1.0, recall: 0.9836
# 2019-03-18T12:29:38.137540, step: 561, loss: 0.05034113675355911, acc: 0.9688, auc: 0.999, precision: 0.9844, recall: 0.9545
# 2019-03-18T12:29:47.439622, step: 562, loss: 0.027508577331900597, acc: 0.9844, auc: 1.0, precision: 1.0, recall: 0.9677
# 2019-03-18T12:29:57.076356, step: 563, loss: 0.07041914761066437, acc: 0.9766, auc: 0.9995, precision: 0.9538, recall: 1.0
# 2019-03-18T12:30:06.477132, step: 564, loss: 0.16382384300231934, acc: 0.9453, auc: 0.9904, precision: 0.9296, recall: 0.9706
# 2019-03-18T12:30:15.878117, step: 565, loss: 0.2023678719997406, acc: 0.9297, auc: 0.9865, precision: 0.9677, recall: 0.8955
# 2019-03-18T12:30:25.528737, step: 566, loss: 0.03804539516568184, acc: 0.9766, auc: 0.999, precision: 0.9848, recall: 0.9701
# 2019-03-18T12:30:35.184440, step: 567, loss: 0.03615004941821098, acc: 0.9844, auc: 0.9993, precision: 0.9828, recall: 0.9828
# 2019-03-18T12:30:44.761082, step: 568, loss: 0.06160542741417885, acc: 0.9844, auc: 0.9995, precision: 1.0, recall: 0.9672
# 2019-03-18T12:30:54.051941, step: 569, loss: 0.08530521392822266, acc: 0.9688, auc: 0.9951, precision: 0.9839, recall: 0.9531
# 2019-03-18T12:31:03.391703, step: 570, loss: 0.1510189175605774, acc: 0.9219, auc: 0.9892, precision: 0.9636, recall: 0.8689
# 2019-03-18T12:31:13.036322, step: 571, loss: 0.10333894938230515, acc: 0.9609, auc: 0.9961, precision: 0.9545, recall: 0.9692
# 2019-03-18T12:31:21.668115, step: 572, loss: 0.056474581360816956, acc: 0.9844, auc: 0.9995, precision: 0.9683, recall: 1.0
# 2019-03-18T12:31:31.101226, step: 573, loss: 0.11123862862586975, acc: 0.9766, auc: 0.9973, precision: 0.9559, recall: 1.0
# 2019-03-18T12:31:40.445394, step: 574, loss: 0.06915938854217529, acc: 0.9766, auc: 0.997, precision: 0.9722, recall: 0.9859
# 2019-03-18T12:31:49.835556, step: 575, loss: 0.05532423034310341, acc: 0.9844, auc: 0.998, precision: 1.0, recall: 0.963
# 2019-03-18T12:31:59.273202, step: 576, loss: 0.05552079156041145, acc: 0.9766, auc: 0.9995, precision: 1.0, recall: 0.9434
# 2019-03-18T12:32:08.459900, step: 577, loss: 0.1856781542301178, acc: 0.9219, auc: 0.9815, precision: 0.9839, recall: 0.8714
# 2019-03-18T12:32:18.262477, step: 578, loss: 0.048658885061740875, acc: 0.9766, auc: 0.9993, precision: 1.0, recall: 0.9524
# 2019-03-18T12:32:27.591428, step: 579, loss: 0.036060333251953125, acc: 0.9844, auc: 0.9998, precision: 0.9853, recall: 0.9853
# 2019-03-18T12:32:36.691667, step: 580, loss: 0.048789918422698975, acc: 0.9922, auc: 0.9992, precision: 1.0, recall: 0.9865
# 2019-03-18T12:32:45.894068, step: 581, loss: 0.07142151147127151, acc: 0.9844, auc: 0.9995, precision: 0.9672, recall: 1.0
# 2019-03-18T12:32:55.440904, step: 582, loss: 0.07047484070062637, acc: 0.9844, auc: 1.0, precision: 0.9677, recall: 1.0
# 2019-03-18T12:33:04.458529, step: 583, loss: 0.06127271056175232, acc: 0.9766, auc: 0.9995, precision: 1.0, recall: 0.9545
# 2019-03-18T12:33:13.775400, step: 584, loss: 0.09713847190141678, acc: 0.9766, auc: 0.987, precision: 1.0, recall: 0.9552
# 2019-03-18T12:33:23.056480, step: 585, loss: 0.0734209343791008, acc: 0.9766, auc: 0.9951, precision: 0.9841, recall: 0.9688
# 2019-03-18T12:33:32.668072, step: 586, loss: 0.14793021976947784, acc: 0.9531, auc: 0.9839, precision: 0.9661, recall: 0.9344
# 2019-03-18T12:33:41.824490, step: 587, loss: 0.039208754897117615, acc: 0.9844, auc: 0.9998, precision: 0.9844, recall: 0.9844
# 2019-03-18T12:33:51.085852, step: 588, loss: 0.06517195701599121, acc: 0.9766, auc: 0.9985, precision: 1.0, recall: 0.9571
# 2019-03-18T12:34:00.881505, step: 589, loss: 0.039579764008522034, acc: 0.9922, auc: 0.9993, precision: 1.0, recall: 0.9851
# 2019-03-18T12:34:09.651284, step: 590, loss: 0.07078371196985245, acc: 0.9844, auc: 0.9966, precision: 0.9672, recall: 1.0
# 2019-03-18T12:34:18.914847, step: 591, loss: 0.06531406939029694, acc: 0.9766, auc: 0.9978, precision: 0.9848, recall: 0.9701
# 2019-03-18T12:34:28.075681, step: 592, loss: 0.04225630685687065, acc: 0.9844, auc: 0.9995, precision: 0.9667, recall: 1.0
# 2019-03-18T12:34:37.722345, step: 593, loss: 0.04648653417825699, acc: 0.9922, auc: 0.996, precision: 0.9861, recall: 1.0
# 2019-03-18T12:34:46.871636, step: 594, loss: 0.0446266233921051, acc: 0.9766, auc: 1.0, precision: 1.0, recall: 0.9552
# 2019-03-18T12:34:56.193780, step: 595, loss: 0.06669391691684723, acc: 0.9688, auc: 0.9975, precision: 0.9825, recall: 0.9492
# 2019-03-18T12:35:05.415082, step: 596, loss: 0.07436156272888184, acc: 0.9844, auc: 0.9928, precision: 0.9825, recall: 0.9825
# 2019-03-18T12:35:14.870045, step: 597, loss: 0.09093542397022247, acc: 0.9844, auc: 0.9941, precision: 0.9825, recall: 0.9825
# 2019-03-18T12:35:23.992899, step: 598, loss: 0.09849581867456436, acc: 0.9766, auc: 0.9917, precision: 0.9683, recall: 0.9839
# 2019-03-18T12:35:33.393566, step: 599, loss: 0.07470138370990753, acc: 0.9766, auc: 0.999, precision: 0.9531, recall: 1.0
# 2019-03-18T12:35:42.905323, step: 600, loss: 0.06209834665060043, acc: 0.9922, auc: 0.991, precision: 0.9841, recall: 1.0
#
# Evaluation:
# 2019-03-18T12:41:42.660841, step: 600, loss: 0.5546396642159193, acc: 0.8463589743589746, auc: 0.9401384615384617, precision: 0.9088128205128206, recall: 0.7746564102564103
# 2019-03-18T12:41:51.597015, step: 601, loss: 0.07795904576778412, acc: 0.9688, auc: 0.9975, precision: 0.9818, recall: 0.9474
# 2019-03-18T12:42:01.057713, step: 602, loss: 0.05925900861620903, acc: 0.9766, auc: 0.9998, precision: 1.0, recall: 0.95
# 2019-03-18T12:42:10.482881, step: 603, loss: 0.10470950603485107, acc: 0.9688, auc: 0.996, precision: 0.9808, recall: 0.9444
# 2019-03-18T12:42:19.968136, step: 604, loss: 0.06366973370313644, acc: 0.9844, auc: 0.998, precision: 1.0, recall: 0.9692
# 2019-03-18T12:42:29.080938, step: 605, loss: 0.03948264196515083, acc: 0.9922, auc: 0.9993, precision: 0.9846, recall: 1.0
# 2019-03-18T12:42:38.464421, step: 606, loss: 0.02407657541334629, acc: 1.0, auc: 1.0, precision: 1.0, recall: 1.0
# 2019-03-18T12:42:47.843274, step: 607, loss: 0.061225615441799164, acc: 0.9688, auc: 0.9993, precision: 0.9571, recall: 0.9853
# 2019-03-18T12:42:57.015887, step: 608, loss: 0.07368534058332443, acc: 0.9766, auc: 0.9946, precision: 0.9833, recall: 0.9672
# 2019-03-18T12:43:06.332364, step: 609, loss: 0.060744088143110275, acc: 0.9688, auc: 0.9983, precision: 0.9655, recall: 0.9655
# 2019-03-18T12:43:16.107300, step: 610, loss: 0.12710882723331451, acc: 0.9609, auc: 0.9841, precision: 0.9839, recall: 0.9385
# 2019-03-18T12:43:25.075887, step: 611, loss: 0.1324993222951889, acc: 0.9375, auc: 0.9961, precision: 1.0, recall: 0.875
# 2019-03-18T12:43:34.195704, step: 612, loss: 0.09485454857349396, acc: 0.9688, auc: 0.9941, precision: 0.9836, recall: 0.9524
# 2019-03-18T12:43:43.328248, step: 613, loss: 0.0578448623418808, acc: 0.9766, auc: 0.9973, precision: 1.0, recall: 0.9545
# 2019-03-18T12:43:53.283896, step: 614, loss: 0.05206224322319031, acc: 0.9922, auc: 1.0, precision: 0.9821, recall: 1.0
# 2019-03-18T12:44:02.727847, step: 615, loss: 0.04539957642555237, acc: 0.9922, auc: 0.9998, precision: 0.9841, recall: 1.0
# 2019-03-18T12:44:12.024026, step: 616, loss: 0.0381392240524292, acc: 0.9922, auc: 1.0, precision: 1.0, recall: 0.9841
# 2019-03-18T12:44:21.785431, step: 617, loss: 0.05110479146242142, acc: 0.9922, auc: 0.9983, precision: 1.0, recall: 0.9848
# 2019-03-18T12:44:31.107133, step: 618, loss: 0.1041361391544342, acc: 0.9688, auc: 0.9933, precision: 1.0, recall: 0.9437
# 2019-03-18T12:44:40.254890, step: 619, loss: 0.01851726323366165, acc: 0.9922, auc: 1.0, precision: 1.0, recall: 0.9857
# 2019-03-18T12:44:49.841338, step: 620, loss: 0.04375505819916725, acc: 0.9844, auc: 0.9993, precision: 1.0, recall: 0.9649
# 2019-03-18T12:44:59.488282, step: 621, loss: 0.03479014337062836, acc: 0.9844, auc: 1.0, precision: 1.0, recall: 0.9722
# 2019-03-18T12:45:08.588591, step: 622, loss: 0.10397469252347946, acc: 0.9766, auc: 0.9946, precision: 0.9701, recall: 0.9848
# 2019-03-18T12:45:17.660939, step: 623, loss: 0.08498898148536682, acc: 0.9766, auc: 0.9941, precision: 0.9844, recall: 0.9692
# 2019-03-18T12:45:26.873620, step: 624, loss: 0.08426922559738159, acc: 0.9609, auc: 0.9977, precision: 0.9153, recall: 1.0
